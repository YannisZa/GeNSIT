# %%
import os
import glob
import optuna
import warnings
import h5py as h5
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

from tqdm.auto import tqdm
from copy import deepcopy

from gensit.config import Config
from gensit.inputs import Inputs
from gensit.outputs import Outputs
from gensit.utils.misc_utils import *
from gensit.utils.math_utils import *
from gensit.utils.probability_utils import *
from gensit.contingency_table import instantiate_ct
from gensit.contingency_table.MarkovBasis import instantiate_markov_basis
from gensit.static.plot_variables import LATEX_RC_PARAMETERS, COLOR_NAMES

# %%
# %matplotlib inline

# AUTO RELOAD EXTERNAL MODULES
# %load_ext autoreload
# %autoreload 2

# %%
# LaTeX font configuration
mpl.rcParams.update(LATEX_RC_PARAMETERS)

# %%
# Create new logging object
logger = setup_logger(
    __name__,
    console_level = 'INFO',
    file_level = 'EMPTY'
)

# %%
output_path = '../../data/outputs/cambridge/exp1/paper_figures/figure3/'

# %% [markdown]
# # Import samples
#
# ## SIM_NN

# %%
# Specify experiment id
sim_nn_experiment_id = "SIM_NN_SweepedNoise_05_12_2023_21_23_00"
# Specify experiment group id
experiment_group_id = 'exp1/'
dataset = 'cambridge'
sim_nn_experiment_dir = f'../../data/outputs/{dataset}/{experiment_group_id}/{sim_nn_experiment_id}/'
sim_nn_relative_experiment_dir = os.path.relpath(sim_nn_experiment_dir,os.getcwd())

# %%
# Output processing settings
sim_nn_settings = {
    "logging_mode": "INFO",
    "coordinate_slice": [
        "da.sigma==0.14142",
        "da.title=='_row_constrained'"
    ],
    "slice":True,
    "metadata_keys":[],
    "burnin_thinning_trimming": [{'iter': {"burnin":0, "thinning":1, "trimming":10000000}}],
    "sample":["intensity"],
    "group_by":[],
    "evaluation_kwargs":['intensity'],
    "filename_ending":"test",
    "force_reload":False,
    "n_workers": 1
}

# %%
# Initialise outputs
simnn_outputs = Outputs(
    config = os.path.join(sim_nn_relative_experiment_dir,"config.json"),
    settings = sim_nn_settings,
    inputs = None,
    slice = True,
    level = 'NOTE'
)
# Silence outputs
simnn_outputs.logger.setLevels(console_level='NOTE')
# Load all data
simnn_outputs.load()

# Get data from first sweep of the SIM_NN experiment
simnn_outputs = simnn_outputs.get(0)
# Out:
# 49:16.882 config INFO ----------------------------------------------------------------------------------
# 49:16.892 config INFO Parameter space size:
#  --- seed (100)
#  --- title: ['title', 'name'] (2)
#  --- sigma: ['sigma', 'to_learn'] (3)
# 49:16.903 config INFO Total = 600.
# 49:16.913 config INFO ----------------------------------------------------------------------------------
# 49:16.952 outputs INFO //////////////////////////////////////////////////////////////////////////////////
# 49:16.962 outputs INFO Slicing coordinates:
# 49:16.972 outputs INFO sigma==0.14142
# 49:16.982 outputs INFO title=='_row_constrained'
# 49:16.993 outputs INFO iter: burnin = 0, thinning = 1, trimming = 10000000
# 49:17.003 outputs INFO //////////////////////////////////////////////////////////////////////////////////
# 49:17.013 outputs WARNING Removing ../../data/outputs/cambridge/exp1/SIM_NN_SweepedNoise_05_12_2023_21_23_00/sample_collections
# 49:17.024 outputs INFO Collecting samples alpha, beta, log_destination_attraction.
# Collecting h5 data sequentially:   0%|          | 0/600 [00:00<?, ?it/s]49:17.118 inputs NOTE Loading Harris Wilson data ...
# 49:17.130 inputs NOTE Margins not provided
# 49:17.140 inputs NOTE Cells subset values file not provided
# 49:17.153 outputs NOTE Loading h5 data into xarrays...
# 49:17.210 outputs NOTE Populating data dictionary
# 49:17.231 outputs PROGRESS Slicing alpha
# 49:17.242 outputs PROGRESS Before coordinate slicing alpha[0]: {'iter': 1000}
# 49:17.286 outputs PROGRESS Slicing beta
# 49:17.296 outputs PROGRESS Before coordinate slicing beta[0]: {'iter': 1000}
# 49:17.340 outputs PROGRESS Slicing log_destination_attraction
# 49:17.350 outputs PROGRESS Before coordinate slicing log_destination_attraction[0]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   0%|          | 1/600 [00:00<03:31,  2.83it/s]49:17.468 inputs NOTE Loading Harris Wilson data ...
# 49:17.479 inputs NOTE Margins not provided
# 49:17.489 inputs NOTE Cells subset values file not provided
# 49:17.501 outputs NOTE Loading h5 data into xarrays...
# 49:17.555 outputs NOTE Populating data dictionary
# 49:17.571 outputs PROGRESS Slicing alpha
# 49:17.580 outputs PROGRESS Before coordinate slicing alpha[1]: {'iter': 1000}
# 49:17.626 outputs PROGRESS Slicing beta
# 49:17.636 outputs PROGRESS Before coordinate slicing beta[1]: {'iter': 1000}
# 49:17.682 outputs PROGRESS Slicing log_destination_attraction
# 49:17.691 outputs PROGRESS Before coordinate slicing log_destination_attraction[1]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   0%|          | 2/600 [00:00<03:28,  2.87it/s]49:17.813 inputs NOTE Loading Harris Wilson data ...
# 49:17.824 inputs NOTE Margins not provided
# 49:17.833 inputs NOTE Cells subset values file not provided
# 49:17.845 outputs NOTE Loading h5 data into xarrays...
# 49:17.898 outputs NOTE Populating data dictionary
# 49:17.914 outputs PROGRESS Slicing alpha
# 49:17.924 outputs PROGRESS Before coordinate slicing alpha[2]: {'iter': 1000}
# 49:17.967 outputs PROGRESS Slicing beta
# 49:17.976 outputs PROGRESS Before coordinate slicing beta[2]: {'iter': 1000}
# 49:18.020 outputs PROGRESS Slicing log_destination_attraction
# 49:18.030 outputs PROGRESS Before coordinate slicing log_destination_attraction[2]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   0%|          | 3/600 [00:01<03:24,  2.92it/s]49:18.148 inputs NOTE Loading Harris Wilson data ...
# 49:18.159 inputs NOTE Margins not provided
# 49:18.168 inputs NOTE Cells subset values file not provided
# 49:18.180 outputs NOTE Loading h5 data into xarrays...
# 49:18.233 outputs NOTE Populating data dictionary
# 49:18.249 outputs PROGRESS Slicing alpha
# 49:18.259 outputs PROGRESS Before coordinate slicing alpha[3]: {'iter': 1000}
# 49:18.301 outputs PROGRESS Slicing beta
# 49:18.311 outputs PROGRESS Before coordinate slicing beta[3]: {'iter': 1000}
# 49:18.354 outputs PROGRESS Slicing log_destination_attraction
# 49:18.364 outputs PROGRESS Before coordinate slicing log_destination_attraction[3]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   1%|          | 4/600 [00:01<03:21,  2.95it/s]49:18.481 inputs NOTE Loading Harris Wilson data ...
# 49:18.492 inputs NOTE Margins not provided
# 49:18.502 inputs NOTE Cells subset values file not provided
# 49:18.514 outputs NOTE Loading h5 data into xarrays...
# 49:18.567 outputs NOTE Populating data dictionary
# 49:18.583 outputs PROGRESS Slicing alpha
# 49:18.593 outputs PROGRESS Before coordinate slicing alpha[4]: {'iter': 1000}
# 49:18.608 outputs PROGRESS After coordinate slicing alpha[4]: {'iter': 1000}
# 49:18.620 outputs PROGRESS After index slicing alpha: {'iter': 1000}
# 49:18.630 outputs PROGRESS alpha: (1, 1, 1, 1, 1, 1000)
# 49:18.645 outputs PROGRESS Slicing beta
# 49:18.655 outputs PROGRESS Before coordinate slicing beta[4]: {'iter': 1000}
# 49:18.671 outputs PROGRESS After coordinate slicing beta[4]: {'iter': 1000}
# 49:18.682 outputs PROGRESS After index slicing beta: {'iter': 1000}
# 49:18.691 outputs PROGRESS beta: (1, 1, 1, 1, 1, 1000)
# 49:18.708 outputs PROGRESS Slicing log_destination_attraction
# 49:18.717 outputs PROGRESS Before coordinate slicing log_destination_attraction[4]: {'iter': 1000, 'destination': 13}
# 49:18.734 outputs PROGRESS After coordinate slicing log_destination_attraction[4]: {'iter': 1000, 'destination': 13}
# 49:18.745 outputs PROGRESS After index slicing log_destination_attraction: {'destination': 13, 'iter': 1000}
# 49:18.755 outputs PROGRESS log_destination_attraction: (1, 1, 1, 1, 1, 13, 1, 1000)
# Collecting h5 data sequentially:   1%|          | 5/600 [00:01<03:26,  2.88it/s]49:18.845 inputs NOTE Loading Harris Wilson data ...
# 49:18.857 inputs NOTE Margins not provided
# 49:18.866 inputs NOTE Cells subset values file not provided
# 49:18.879 outputs NOTE Loading h5 data into xarrays...
# 49:18.932 outputs NOTE Populating data dictionary
# 49:18.948 outputs PROGRESS Slicing alpha
# 49:18.958 outputs PROGRESS Before coordinate slicing alpha[5]: {'iter': 1000}
# 49:19.002 outputs PROGRESS Slicing beta
# 49:19.012 outputs PROGRESS Before coordinate slicing beta[5]: {'iter': 1000}
# 49:19.056 outputs PROGRESS Slicing log_destination_attraction
# 49:19.065 outputs PROGRESS Before coordinate slicing log_destination_attraction[5]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   1%|          | 6/600 [00:02<03:24,  2.90it/s]49:19.183 inputs NOTE Loading Harris Wilson data ...
# 49:19.194 inputs NOTE Margins not provided
# 49:19.204 inputs NOTE Cells subset values file not provided
# 49:19.215 outputs NOTE Loading h5 data into xarrays...
# 49:19.268 outputs NOTE Populating data dictionary
# 49:19.284 outputs PROGRESS Slicing alpha
# 49:19.294 outputs PROGRESS Before coordinate slicing alpha[6]: {'iter': 1000}
# 49:19.337 outputs PROGRESS Slicing beta
# 49:19.347 outputs PROGRESS Before coordinate slicing beta[6]: {'iter': 1000}
# 49:19.391 outputs PROGRESS Slicing log_destination_attraction
# 49:19.400 outputs PROGRESS Before coordinate slicing log_destination_attraction[6]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   1%|          | 7/600 [00:02<03:22,  2.93it/s]49:19.517 inputs NOTE Loading Harris Wilson data ...
# 49:19.529 inputs NOTE Margins not provided
# 49:19.538 inputs NOTE Cells subset values file not provided
# 49:19.550 outputs NOTE Loading h5 data into xarrays...
# 49:19.603 outputs NOTE Populating data dictionary
# 49:19.619 outputs PROGRESS Slicing alpha
# 49:19.629 outputs PROGRESS Before coordinate slicing alpha[7]: {'iter': 1000}
# 49:19.675 outputs PROGRESS Slicing beta
# 49:19.685 outputs PROGRESS Before coordinate slicing beta[7]: {'iter': 1000}
# 49:19.732 outputs PROGRESS Slicing log_destination_attraction
# 49:19.741 outputs PROGRESS Before coordinate slicing log_destination_attraction[7]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   1%|▏         | 8/600 [00:02<03:22,  2.92it/s]49:19.862 inputs NOTE Loading Harris Wilson data ...
# 49:19.873 inputs NOTE Margins not provided
# 49:19.883 inputs NOTE Cells subset values file not provided
# 49:19.895 outputs NOTE Loading h5 data into xarrays...
# 49:19.947 outputs NOTE Populating data dictionary
# 49:19.963 outputs PROGRESS Slicing alpha
# 49:19.972 outputs PROGRESS Before coordinate slicing alpha[8]: {'iter': 1000}
# 49:20.015 outputs PROGRESS Slicing beta
# 49:20.025 outputs PROGRESS Before coordinate slicing beta[8]: {'iter': 1000}
# 49:20.068 outputs PROGRESS Slicing log_destination_attraction
# 49:20.078 outputs PROGRESS Before coordinate slicing log_destination_attraction[8]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   2%|▏         | 9/600 [00:03<03:20,  2.94it/s]49:20.196 inputs NOTE Loading Harris Wilson data ...
# 49:20.207 inputs NOTE Margins not provided
# 49:20.216 inputs NOTE Cells subset values file not provided
# 49:20.228 outputs NOTE Loading h5 data into xarrays...
# 49:20.281 outputs NOTE Populating data dictionary
# 49:20.297 outputs PROGRESS Slicing alpha
# 49:20.307 outputs PROGRESS Before coordinate slicing alpha[9]: {'iter': 1000}
# 49:20.350 outputs PROGRESS Slicing beta
# 49:20.360 outputs PROGRESS Before coordinate slicing beta[9]: {'iter': 1000}
# 49:20.404 outputs PROGRESS Slicing log_destination_attraction
# 49:20.414 outputs PROGRESS Before coordinate slicing log_destination_attraction[9]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   2%|▏         | 10/600 [00:03<03:19,  2.95it/s]49:20.533 inputs NOTE Loading Harris Wilson data ...
# 49:20.544 inputs NOTE Margins not provided
# 49:20.553 inputs NOTE Cells subset values file not provided
# 49:20.565 outputs NOTE Loading h5 data into xarrays...
# 49:20.619 outputs NOTE Populating data dictionary
# 49:20.635 outputs PROGRESS Slicing alpha
# 49:20.645 outputs PROGRESS Before coordinate slicing alpha[10]: {'iter': 1000}
# 49:20.660 outputs PROGRESS After coordinate slicing alpha[10]: {'iter': 1000}
# 49:20.671 outputs PROGRESS After index slicing alpha: {'iter': 1000}
# 49:20.681 outputs PROGRESS alpha: (1, 1, 1, 1, 1, 1000)
# 49:20.696 outputs PROGRESS Slicing beta
# 49:20.706 outputs PROGRESS Before coordinate slicing beta[10]: {'iter': 1000}
# 49:20.722 outputs PROGRESS After coordinate slicing beta[10]: {'iter': 1000}
# 49:20.733 outputs PROGRESS After index slicing beta: {'iter': 1000}
# 49:20.743 outputs PROGRESS beta: (1, 1, 1, 1, 1, 1000)
# 49:20.759 outputs PROGRESS Slicing log_destination_attraction
# 49:20.768 outputs PROGRESS Before coordinate slicing log_destination_attraction[10]: {'iter': 1000, 'destination': 13}
# 49:20.812 outputs PROGRESS After coordinate slicing log_destination_attraction[10]: {'iter': 1000, 'destination': 13}
# 49:20.833 outputs PROGRESS After index slicing log_destination_attraction: {'destination': 13, 'iter': 1000}
# 49:20.850 outputs PROGRESS log_destination_attraction: (1, 1, 1, 1, 1, 13, 1, 1000)
# Collecting h5 data sequentially:   2%|▏         | 11/600 [00:03<03:31,  2.78it/s]49:20.965 inputs NOTE Loading Harris Wilson data ...
# 49:20.976 inputs NOTE Margins not provided
# 49:20.986 inputs NOTE Cells subset values file not provided
# 49:20.998 outputs NOTE Loading h5 data into xarrays...
# 49:21.052 outputs NOTE Populating data dictionary
# 49:21.067 outputs PROGRESS Slicing alpha
# 49:21.077 outputs PROGRESS Before coordinate slicing alpha[11]: {'iter': 1000}
# 49:21.119 outputs PROGRESS Slicing beta
# 49:21.129 outputs PROGRESS Before coordinate slicing beta[11]: {'iter': 1000}
# 49:21.172 outputs PROGRESS Slicing log_destination_attraction
# 49:21.182 outputs PROGRESS Before coordinate slicing log_destination_attraction[11]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   2%|▏         | 12/600 [00:04<03:31,  2.78it/s]49:21.299 inputs NOTE Loading Harris Wilson data ...
# 49:21.310 inputs NOTE Margins not provided
# 49:21.320 inputs NOTE Cells subset values file not provided
# 49:21.332 outputs NOTE Loading h5 data into xarrays...
# 49:21.385 outputs NOTE Populating data dictionary
# 49:21.400 outputs PROGRESS Slicing alpha
# 49:21.410 outputs PROGRESS Before coordinate slicing alpha[12]: {'iter': 1000}
# 49:21.453 outputs PROGRESS Slicing beta
# 49:21.463 outputs PROGRESS Before coordinate slicing beta[12]: {'iter': 1000}
# 49:21.506 outputs PROGRESS Slicing log_destination_attraction
# 49:21.516 outputs PROGRESS Before coordinate slicing log_destination_attraction[12]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   2%|▏         | 13/600 [00:04<03:26,  2.84it/s]49:21.634 inputs NOTE Loading Harris Wilson data ...
# 49:21.645 inputs NOTE Margins not provided
# 49:21.654 inputs NOTE Cells subset values file not provided
# 49:21.666 outputs NOTE Loading h5 data into xarrays...
# 49:21.719 outputs NOTE Populating data dictionary
# 49:21.735 outputs PROGRESS Slicing alpha
# 49:21.745 outputs PROGRESS Before coordinate slicing alpha[13]: {'iter': 1000}
# 49:21.791 outputs PROGRESS Slicing beta
# 49:21.801 outputs PROGRESS Before coordinate slicing beta[13]: {'iter': 1000}
# 49:21.847 outputs PROGRESS Slicing log_destination_attraction
# 49:21.857 outputs PROGRESS Before coordinate slicing log_destination_attraction[13]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   2%|▏         | 14/600 [00:04<03:24,  2.86it/s]49:21.978 inputs NOTE Loading Harris Wilson data ...
# 49:21.989 inputs NOTE Margins not provided
# 49:21.999 inputs NOTE Cells subset values file not provided
# 49:22.011 outputs NOTE Loading h5 data into xarrays...
# 49:22.064 outputs NOTE Populating data dictionary
# 49:22.080 outputs PROGRESS Slicing alpha
# 49:22.089 outputs PROGRESS Before coordinate slicing alpha[14]: {'iter': 1000}
# 49:22.132 outputs PROGRESS Slicing beta
# 49:22.142 outputs PROGRESS Before coordinate slicing beta[14]: {'iter': 1000}
# 49:22.185 outputs PROGRESS Slicing log_destination_attraction
# 49:22.195 outputs PROGRESS Before coordinate slicing log_destination_attraction[14]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   2%|▎         | 15/600 [00:05<03:21,  2.90it/s]49:22.312 inputs NOTE Loading Harris Wilson data ...
# 49:22.323 inputs NOTE Margins not provided
# 49:22.333 inputs NOTE Cells subset values file not provided
# 49:22.345 outputs NOTE Loading h5 data into xarrays...
# 49:22.399 outputs NOTE Populating data dictionary
# 49:22.415 outputs PROGRESS Slicing alpha
# 49:22.424 outputs PROGRESS Before coordinate slicing alpha[15]: {'iter': 1000}
# 49:22.468 outputs PROGRESS Slicing beta
# 49:22.477 outputs PROGRESS Before coordinate slicing beta[15]: {'iter': 1000}
# 49:22.521 outputs PROGRESS Slicing log_destination_attraction
# 49:22.531 outputs PROGRESS Before coordinate slicing log_destination_attraction[15]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   3%|▎         | 16/600 [00:05<03:20,  2.92it/s]49:22.649 inputs NOTE Loading Harris Wilson data ...
# 49:22.660 inputs NOTE Margins not provided
# 49:22.669 inputs NOTE Cells subset values file not provided
# 49:22.681 outputs NOTE Loading h5 data into xarrays...
# 49:22.735 outputs NOTE Populating data dictionary
# 49:22.751 outputs PROGRESS Slicing alpha
# 49:22.760 outputs PROGRESS Before coordinate slicing alpha[16]: {'iter': 1000}
# 49:22.775 outputs PROGRESS After coordinate slicing alpha[16]: {'iter': 1000}
# 49:22.787 outputs PROGRESS After index slicing alpha: {'iter': 1000}
# 49:22.796 outputs PROGRESS alpha: (1, 1, 1, 1, 1, 1000)
# 49:22.812 outputs PROGRESS Slicing beta
# 49:22.821 outputs PROGRESS Before coordinate slicing beta[16]: {'iter': 1000}
# 49:22.837 outputs PROGRESS After coordinate slicing beta[16]: {'iter': 1000}
# 49:22.848 outputs PROGRESS After index slicing beta: {'iter': 1000}
# 49:22.858 outputs PROGRESS beta: (1, 1, 1, 1, 1, 1000)
# 49:22.874 outputs PROGRESS Slicing log_destination_attraction
# 49:22.884 outputs PROGRESS Before coordinate slicing log_destination_attraction[16]: {'iter': 1000, 'destination': 13}
# 49:22.900 outputs PROGRESS After coordinate slicing log_destination_attraction[16]: {'iter': 1000, 'destination': 13}
# 49:22.912 outputs PROGRESS After index slicing log_destination_attraction: {'destination': 13, 'iter': 1000}
# 49:22.921 outputs PROGRESS log_destination_attraction: (1, 1, 1, 1, 1, 13, 1, 1000)
# Collecting h5 data sequentially:   3%|▎         | 17/600 [00:05<03:22,  2.87it/s]49:23.011 inputs NOTE Loading Harris Wilson data ...
# 49:23.022 inputs NOTE Margins not provided
# 49:23.032 inputs NOTE Cells subset values file not provided
# 49:23.044 outputs NOTE Loading h5 data into xarrays...
# 49:23.097 outputs NOTE Populating data dictionary
# 49:23.114 outputs PROGRESS Slicing alpha
# 49:23.123 outputs PROGRESS Before coordinate slicing alpha[17]: {'iter': 1000}
# 49:23.166 outputs PROGRESS Slicing beta
# 49:23.176 outputs PROGRESS Before coordinate slicing beta[17]: {'iter': 1000}
# 49:23.219 outputs PROGRESS Slicing log_destination_attraction
# 49:23.228 outputs PROGRESS Before coordinate slicing log_destination_attraction[17]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   3%|▎         | 18/600 [00:06<03:20,  2.90it/s]49:23.346 inputs NOTE Loading Harris Wilson data ...
# 49:23.357 inputs NOTE Margins not provided
# 49:23.366 inputs NOTE Cells subset values file not provided
# 49:23.378 outputs NOTE Loading h5 data into xarrays...
# 49:23.431 outputs NOTE Populating data dictionary
# 49:23.447 outputs PROGRESS Slicing alpha
# 49:23.470 outputs PROGRESS Before coordinate slicing alpha[18]: {'iter': 1000}
# 49:23.545 outputs PROGRESS Slicing beta
# 49:23.557 outputs PROGRESS Before coordinate slicing beta[18]: {'iter': 1000}
# 49:23.606 outputs PROGRESS Slicing log_destination_attraction
# 49:23.616 outputs PROGRESS Before coordinate slicing log_destination_attraction[18]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   3%|▎         | 19/600 [00:06<03:27,  2.80it/s]49:23.733 inputs NOTE Loading Harris Wilson data ...
# 49:23.744 inputs NOTE Margins not provided
# 49:23.754 inputs NOTE Cells subset values file not provided
# 49:23.766 outputs NOTE Loading h5 data into xarrays...
# 49:23.819 outputs NOTE Populating data dictionary
# 49:23.835 outputs PROGRESS Slicing alpha
# 49:23.844 outputs PROGRESS Before coordinate slicing alpha[19]: {'iter': 1000}
# 49:23.890 outputs PROGRESS Slicing beta
# 49:23.900 outputs PROGRESS Before coordinate slicing beta[19]: {'iter': 1000}
# 49:23.947 outputs PROGRESS Slicing log_destination_attraction
# 49:23.956 outputs PROGRESS Before coordinate slicing log_destination_attraction[19]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   3%|▎         | 20/600 [00:06<03:24,  2.83it/s]49:24.076 inputs NOTE Loading Harris Wilson data ...
# 49:24.087 inputs NOTE Margins not provided
# 49:24.097 inputs NOTE Cells subset values file not provided
# 49:24.109 outputs NOTE Loading h5 data into xarrays...
# 49:24.163 outputs NOTE Populating data dictionary
# 49:24.179 outputs PROGRESS Slicing alpha
# 49:24.188 outputs PROGRESS Before coordinate slicing alpha[20]: {'iter': 1000}
# 49:24.231 outputs PROGRESS Slicing beta
# 49:24.241 outputs PROGRESS Before coordinate slicing beta[20]: {'iter': 1000}
# 49:24.284 outputs PROGRESS Slicing log_destination_attraction
# 49:24.293 outputs PROGRESS Before coordinate slicing log_destination_attraction[20]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   4%|▎         | 21/600 [00:07<03:21,  2.88it/s]49:24.413 inputs NOTE Loading Harris Wilson data ...
# 49:24.424 inputs NOTE Margins not provided
# 49:24.434 inputs NOTE Cells subset values file not provided
# 49:24.446 outputs NOTE Loading h5 data into xarrays...
# 49:24.500 outputs NOTE Populating data dictionary
# 49:24.516 outputs PROGRESS Slicing alpha
# 49:24.525 outputs PROGRESS Before coordinate slicing alpha[21]: {'iter': 1000}
# 49:24.568 outputs PROGRESS Slicing beta
# 49:24.578 outputs PROGRESS Before coordinate slicing beta[21]: {'iter': 1000}
# 49:24.622 outputs PROGRESS Slicing log_destination_attraction
# 49:24.631 outputs PROGRESS Before coordinate slicing log_destination_attraction[21]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   4%|▎         | 22/600 [00:07<03:19,  2.90it/s]49:24.749 inputs NOTE Loading Harris Wilson data ...
# 49:24.761 inputs NOTE Margins not provided
# 49:24.770 inputs NOTE Cells subset values file not provided
# 49:24.782 outputs NOTE Loading h5 data into xarrays...
# 49:24.835 outputs NOTE Populating data dictionary
# 49:24.852 outputs PROGRESS Slicing alpha
# 49:24.861 outputs PROGRESS Before coordinate slicing alpha[22]: {'iter': 1000}
# 49:24.877 outputs PROGRESS After coordinate slicing alpha[22]: {'iter': 1000}
# 49:24.888 outputs PROGRESS After index slicing alpha: {'iter': 1000}
# 49:24.898 outputs PROGRESS alpha: (1, 1, 1, 1, 1, 1000)
# 49:24.914 outputs PROGRESS Slicing beta
# 49:24.923 outputs PROGRESS Before coordinate slicing beta[22]: {'iter': 1000}
# 49:24.939 outputs PROGRESS After coordinate slicing beta[22]: {'iter': 1000}
# 49:24.950 outputs PROGRESS After index slicing beta: {'iter': 1000}
# 49:24.960 outputs PROGRESS beta: (1, 1, 1, 1, 1, 1000)
# 49:24.976 outputs PROGRESS Slicing log_destination_attraction
# 49:24.985 outputs PROGRESS Before coordinate slicing log_destination_attraction[22]: {'iter': 1000, 'destination': 13}
# 49:25.002 outputs PROGRESS After coordinate slicing log_destination_attraction[22]: {'iter': 1000, 'destination': 13}
# 49:25.013 outputs PROGRESS After index slicing log_destination_attraction: {'destination': 13, 'iter': 1000}
# 49:25.023 outputs PROGRESS log_destination_attraction: (1, 1, 1, 1, 1, 13, 1, 1000)
# Collecting h5 data sequentially:   4%|▍         | 23/600 [00:07<03:21,  2.86it/s]49:25.116 inputs NOTE Loading Harris Wilson data ...
# 49:25.127 inputs NOTE Margins not provided
# 49:25.137 inputs NOTE Cells subset values file not provided
# 49:25.149 outputs NOTE Loading h5 data into xarrays...
# 49:25.202 outputs NOTE Populating data dictionary
# 49:25.218 outputs PROGRESS Slicing alpha
# 49:25.228 outputs PROGRESS Before coordinate slicing alpha[23]: {'iter': 1000}
# 49:25.271 outputs PROGRESS Slicing beta
# 49:25.280 outputs PROGRESS Before coordinate slicing beta[23]: {'iter': 1000}
# 49:25.324 outputs PROGRESS Slicing log_destination_attraction
# 49:25.334 outputs PROGRESS Before coordinate slicing log_destination_attraction[23]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   4%|▍         | 24/600 [00:08<03:19,  2.88it/s]49:25.452 inputs NOTE Loading Harris Wilson data ...
# 49:25.463 inputs NOTE Margins not provided
# 49:25.473 inputs NOTE Cells subset values file not provided
# 49:25.485 outputs NOTE Loading h5 data into xarrays...
# 49:25.538 outputs NOTE Populating data dictionary
# 49:25.555 outputs PROGRESS Slicing alpha
# 49:25.564 outputs PROGRESS Before coordinate slicing alpha[24]: {'iter': 1000}
# 49:25.607 outputs PROGRESS Slicing beta
# 49:25.617 outputs PROGRESS Before coordinate slicing beta[24]: {'iter': 1000}
# 49:25.661 outputs PROGRESS Slicing log_destination_attraction
# 49:25.671 outputs PROGRESS Before coordinate slicing log_destination_attraction[24]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   4%|▍         | 25/600 [00:08<03:17,  2.91it/s]49:25.788 inputs NOTE Loading Harris Wilson data ...
# 49:25.799 inputs NOTE Margins not provided
# 49:25.809 inputs NOTE Cells subset values file not provided
# 49:25.821 outputs NOTE Loading h5 data into xarrays...
# 49:25.875 outputs NOTE Populating data dictionary
# 49:25.892 outputs PROGRESS Slicing alpha
# 49:25.901 outputs PROGRESS Before coordinate slicing alpha[25]: {'iter': 1000}
# 49:25.947 outputs PROGRESS Slicing beta
# 49:25.957 outputs PROGRESS Before coordinate slicing beta[25]: {'iter': 1000}
# 49:26.003 outputs PROGRESS Slicing log_destination_attraction
# 49:26.013 outputs PROGRESS Before coordinate slicing log_destination_attraction[25]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   4%|▍         | 26/600 [00:09<03:17,  2.90it/s]49:26.134 inputs NOTE Loading Harris Wilson data ...
# 49:26.145 inputs NOTE Margins not provided
# 49:26.155 inputs NOTE Cells subset values file not provided
# 49:26.167 outputs NOTE Loading h5 data into xarrays...
# 49:26.220 outputs NOTE Populating data dictionary
# 49:26.236 outputs PROGRESS Slicing alpha
# 49:26.245 outputs PROGRESS Before coordinate slicing alpha[26]: {'iter': 1000}
# 49:26.288 outputs PROGRESS Slicing beta
# 49:26.298 outputs PROGRESS Before coordinate slicing beta[26]: {'iter': 1000}
# 49:26.341 outputs PROGRESS Slicing log_destination_attraction
# 49:26.350 outputs PROGRESS Before coordinate slicing log_destination_attraction[26]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   4%|▍         | 27/600 [00:09<03:15,  2.93it/s]49:26.469 inputs NOTE Loading Harris Wilson data ...
# 49:26.480 inputs NOTE Margins not provided
# 49:26.490 inputs NOTE Cells subset values file not provided
# 49:26.501 outputs NOTE Loading h5 data into xarrays...
# 49:26.555 outputs NOTE Populating data dictionary
# 49:26.571 outputs PROGRESS Slicing alpha
# 49:26.581 outputs PROGRESS Before coordinate slicing alpha[27]: {'iter': 1000}
# 49:26.624 outputs PROGRESS Slicing beta
# 49:26.634 outputs PROGRESS Before coordinate slicing beta[27]: {'iter': 1000}
# 49:26.677 outputs PROGRESS Slicing log_destination_attraction
# 49:26.687 outputs PROGRESS Before coordinate slicing log_destination_attraction[27]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   5%|▍         | 28/600 [00:09<03:14,  2.94it/s]49:26.805 inputs NOTE Loading Harris Wilson data ...
# 49:26.816 inputs NOTE Margins not provided
# 49:26.826 inputs NOTE Cells subset values file not provided
# 49:26.838 outputs NOTE Loading h5 data into xarrays...
# 49:26.892 outputs NOTE Populating data dictionary
# 49:26.908 outputs PROGRESS Slicing alpha
# 49:26.917 outputs PROGRESS Before coordinate slicing alpha[28]: {'iter': 1000}
# 49:26.933 outputs PROGRESS After coordinate slicing alpha[28]: {'iter': 1000}
# 49:26.944 outputs PROGRESS After index slicing alpha: {'iter': 1000}
# 49:26.954 outputs PROGRESS alpha: (1, 1, 1, 1, 1, 1000)
# 49:26.969 outputs PROGRESS Slicing beta
# 49:26.978 outputs PROGRESS Before coordinate slicing beta[28]: {'iter': 1000}
# 49:26.994 outputs PROGRESS After coordinate slicing beta[28]: {'iter': 1000}
# 49:27.005 outputs PROGRESS After index slicing beta: {'iter': 1000}
# 49:27.015 outputs PROGRESS beta: (1, 1, 1, 1, 1, 1000)
# 49:27.031 outputs PROGRESS Slicing log_destination_attraction
# 49:27.041 outputs PROGRESS Before coordinate slicing log_destination_attraction[28]: {'iter': 1000, 'destination': 13}
# 49:27.058 outputs PROGRESS After coordinate slicing log_destination_attraction[28]: {'iter': 1000, 'destination': 13}
# 49:27.070 outputs PROGRESS After index slicing log_destination_attraction: {'destination': 13, 'iter': 1000}
# 49:27.079 outputs PROGRESS log_destination_attraction: (1, 1, 1, 1, 1, 13, 1, 1000)
# Collecting h5 data sequentially:   5%|▍         | 29/600 [00:10<03:18,  2.88it/s]49:27.170 inputs NOTE Loading Harris Wilson data ...
# 49:27.181 inputs NOTE Margins not provided
# 49:27.190 inputs NOTE Cells subset values file not provided
# 49:27.203 outputs NOTE Loading h5 data into xarrays...
# 49:27.256 outputs NOTE Populating data dictionary
# 49:27.272 outputs PROGRESS Slicing alpha
# 49:27.282 outputs PROGRESS Before coordinate slicing alpha[29]: {'iter': 1000}
# 49:27.325 outputs PROGRESS Slicing beta
# 49:27.335 outputs PROGRESS Before coordinate slicing beta[29]: {'iter': 1000}
# 49:27.378 outputs PROGRESS Slicing log_destination_attraction
# 49:27.388 outputs PROGRESS Before coordinate slicing log_destination_attraction[29]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   5%|▌         | 30/600 [00:10<03:16,  2.91it/s]49:27.505 inputs NOTE Loading Harris Wilson data ...
# 49:27.516 inputs NOTE Margins not provided
# 49:27.526 inputs NOTE Cells subset values file not provided
# 49:27.538 outputs NOTE Loading h5 data into xarrays...
# 49:27.591 outputs NOTE Populating data dictionary
# 49:27.606 outputs PROGRESS Slicing alpha
# 49:27.616 outputs PROGRESS Before coordinate slicing alpha[30]: {'iter': 1000}
# 49:27.659 outputs PROGRESS Slicing beta
# 49:27.668 outputs PROGRESS Before coordinate slicing beta[30]: {'iter': 1000}
# 49:27.712 outputs PROGRESS Slicing log_destination_attraction
# 49:27.722 outputs PROGRESS Before coordinate slicing log_destination_attraction[30]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   5%|▌         | 31/600 [00:10<03:14,  2.93it/s]49:27.839 inputs NOTE Loading Harris Wilson data ...
# 49:27.850 inputs NOTE Margins not provided
# 49:27.859 inputs NOTE Cells subset values file not provided
# 49:27.871 outputs NOTE Loading h5 data into xarrays...
# 49:27.924 outputs NOTE Populating data dictionary
# 49:27.940 outputs PROGRESS Slicing alpha
# 49:27.949 outputs PROGRESS Before coordinate slicing alpha[31]: {'iter': 1000}
# 49:27.995 outputs PROGRESS Slicing beta
# 49:28.005 outputs PROGRESS Before coordinate slicing beta[31]: {'iter': 1000}
# 49:28.051 outputs PROGRESS Slicing log_destination_attraction
# 49:28.061 outputs PROGRESS Before coordinate slicing log_destination_attraction[31]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   5%|▌         | 32/600 [00:11<03:13,  2.93it/s]49:28.182 inputs NOTE Loading Harris Wilson data ...
# 49:28.193 inputs NOTE Margins not provided
# 49:28.203 inputs NOTE Cells subset values file not provided
# 49:28.215 outputs NOTE Loading h5 data into xarrays...
# 49:28.267 outputs NOTE Populating data dictionary
# 49:28.284 outputs PROGRESS Slicing alpha
# 49:28.293 outputs PROGRESS Before coordinate slicing alpha[32]: {'iter': 1000}
# 49:28.336 outputs PROGRESS Slicing beta
# 49:28.345 outputs PROGRESS Before coordinate slicing beta[32]: {'iter': 1000}
# 49:28.388 outputs PROGRESS Slicing log_destination_attraction
# 49:28.398 outputs PROGRESS Before coordinate slicing log_destination_attraction[32]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   6%|▌         | 33/600 [00:11<03:12,  2.95it/s]49:28.517 inputs NOTE Loading Harris Wilson data ...
# 49:28.528 inputs NOTE Margins not provided
# 49:28.537 inputs NOTE Cells subset values file not provided
# 49:28.549 outputs NOTE Loading h5 data into xarrays...
# 49:28.602 outputs NOTE Populating data dictionary
# 49:28.618 outputs PROGRESS Slicing alpha
# 49:28.628 outputs PROGRESS Before coordinate slicing alpha[33]: {'iter': 1000}
# 49:28.671 outputs PROGRESS Slicing beta
# 49:28.680 outputs PROGRESS Before coordinate slicing beta[33]: {'iter': 1000}
# 49:28.723 outputs PROGRESS Slicing log_destination_attraction
# 49:28.733 outputs PROGRESS Before coordinate slicing log_destination_attraction[33]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   6%|▌         | 34/600 [00:11<03:11,  2.96it/s]49:28.850 inputs NOTE Loading Harris Wilson data ...
# 49:28.861 inputs NOTE Margins not provided
# 49:28.871 inputs NOTE Cells subset values file not provided
# 49:28.882 outputs NOTE Loading h5 data into xarrays...
# 49:28.936 outputs NOTE Populating data dictionary
# 49:28.951 outputs PROGRESS Slicing alpha
# 49:28.961 outputs PROGRESS Before coordinate slicing alpha[34]: {'iter': 1000}
# 49:28.976 outputs PROGRESS After coordinate slicing alpha[34]: {'iter': 1000}
# 49:28.988 outputs PROGRESS After index slicing alpha: {'iter': 1000}
# 49:28.997 outputs PROGRESS alpha: (1, 1, 1, 1, 1, 1000)
# 49:29.013 outputs PROGRESS Slicing beta
# 49:29.023 outputs PROGRESS Before coordinate slicing beta[34]: {'iter': 1000}
# 49:29.038 outputs PROGRESS After coordinate slicing beta[34]: {'iter': 1000}
# 49:29.050 outputs PROGRESS After index slicing beta: {'iter': 1000}
# 49:29.060 outputs PROGRESS beta: (1, 1, 1, 1, 1, 1000)
# 49:29.076 outputs PROGRESS Slicing log_destination_attraction
# 49:29.085 outputs PROGRESS Before coordinate slicing log_destination_attraction[34]: {'iter': 1000, 'destination': 13}
# 49:29.102 outputs PROGRESS After coordinate slicing log_destination_attraction[34]: {'iter': 1000, 'destination': 13}
# 49:29.113 outputs PROGRESS After index slicing log_destination_attraction: {'destination': 13, 'iter': 1000}
# 49:29.123 outputs PROGRESS log_destination_attraction: (1, 1, 1, 1, 1, 13, 1, 1000)
# Collecting h5 data sequentially:   6%|▌         | 35/600 [00:12<03:14,  2.90it/s]49:29.214 inputs NOTE Loading Harris Wilson data ...
# 49:29.225 inputs NOTE Margins not provided
# 49:29.234 inputs NOTE Cells subset values file not provided
# 49:29.246 outputs NOTE Loading h5 data into xarrays...
# 49:29.299 outputs NOTE Populating data dictionary
# 49:29.316 outputs PROGRESS Slicing alpha
# 49:29.325 outputs PROGRESS Before coordinate slicing alpha[35]: {'iter': 1000}
# 49:29.368 outputs PROGRESS Slicing beta
# 49:29.378 outputs PROGRESS Before coordinate slicing beta[35]: {'iter': 1000}
# 49:29.422 outputs PROGRESS Slicing log_destination_attraction
# 49:29.431 outputs PROGRESS Before coordinate slicing log_destination_attraction[35]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   6%|▌         | 36/600 [00:12<03:13,  2.92it/s]49:29.549 inputs NOTE Loading Harris Wilson data ...
# 49:29.560 inputs NOTE Margins not provided
# 49:29.570 inputs NOTE Cells subset values file not provided
# 49:29.581 outputs NOTE Loading h5 data into xarrays...
# 49:29.635 outputs NOTE Populating data dictionary
# 49:29.651 outputs PROGRESS Slicing alpha
# 49:29.660 outputs PROGRESS Before coordinate slicing alpha[36]: {'iter': 1000}
# 49:29.704 outputs PROGRESS Slicing beta
# 49:29.714 outputs PROGRESS Before coordinate slicing beta[36]: {'iter': 1000}
# 49:29.757 outputs PROGRESS Slicing log_destination_attraction
# 49:29.767 outputs PROGRESS Before coordinate slicing log_destination_attraction[36]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   6%|▌         | 37/600 [00:12<03:11,  2.94it/s]49:29.885 inputs NOTE Loading Harris Wilson data ...
# 49:29.896 inputs NOTE Margins not provided
# 49:29.906 inputs NOTE Cells subset values file not provided
# 49:29.918 outputs NOTE Loading h5 data into xarrays...
# 49:29.971 outputs NOTE Populating data dictionary
# 49:29.987 outputs PROGRESS Slicing alpha
# 49:29.996 outputs PROGRESS Before coordinate slicing alpha[37]: {'iter': 1000}
# 49:30.042 outputs PROGRESS Slicing beta
# 49:30.052 outputs PROGRESS Before coordinate slicing beta[37]: {'iter': 1000}
# 49:30.098 outputs PROGRESS Slicing log_destination_attraction
# 49:30.108 outputs PROGRESS Before coordinate slicing log_destination_attraction[37]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   6%|▋         | 38/600 [00:13<03:11,  2.93it/s]49:30.229 inputs NOTE Loading Harris Wilson data ...
# 49:30.240 inputs NOTE Margins not provided
# 49:30.250 inputs NOTE Cells subset values file not provided
# 49:30.262 outputs NOTE Loading h5 data into xarrays...
# 49:30.315 outputs NOTE Populating data dictionary
# 49:30.331 outputs PROGRESS Slicing alpha
# 49:30.340 outputs PROGRESS Before coordinate slicing alpha[38]: {'iter': 1000}
# 49:30.382 outputs PROGRESS Slicing beta
# 49:30.392 outputs PROGRESS Before coordinate slicing beta[38]: {'iter': 1000}
# 49:30.436 outputs PROGRESS Slicing log_destination_attraction
# 49:30.446 outputs PROGRESS Before coordinate slicing log_destination_attraction[38]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   6%|▋         | 39/600 [00:13<03:10,  2.95it/s]49:30.563 inputs NOTE Loading Harris Wilson data ...
# 49:30.575 inputs NOTE Margins not provided
# 49:30.584 inputs NOTE Cells subset values file not provided
# 49:30.596 outputs NOTE Loading h5 data into xarrays...
# 49:30.650 outputs NOTE Populating data dictionary
# 49:30.666 outputs PROGRESS Slicing alpha
# 49:30.676 outputs PROGRESS Before coordinate slicing alpha[39]: {'iter': 1000}
# 49:30.718 outputs PROGRESS Slicing beta
# 49:30.728 outputs PROGRESS Before coordinate slicing beta[39]: {'iter': 1000}
# 49:30.772 outputs PROGRESS Slicing log_destination_attraction
# 49:30.781 outputs PROGRESS Before coordinate slicing log_destination_attraction[39]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   7%|▋         | 40/600 [00:13<03:09,  2.96it/s]49:30.899 inputs NOTE Loading Harris Wilson data ...
# 49:30.910 inputs NOTE Margins not provided
# 49:30.920 inputs NOTE Cells subset values file not provided
# 49:30.931 outputs NOTE Loading h5 data into xarrays...
# 49:30.984 outputs NOTE Populating data dictionary
# 49:31.000 outputs PROGRESS Slicing alpha
# 49:31.010 outputs PROGRESS Before coordinate slicing alpha[40]: {'iter': 1000}
# 49:31.025 outputs PROGRESS After coordinate slicing alpha[40]: {'iter': 1000}
# 49:31.037 outputs PROGRESS After index slicing alpha: {'iter': 1000}
# 49:31.046 outputs PROGRESS alpha: (1, 1, 1, 1, 1, 1000)
# 49:31.062 outputs PROGRESS Slicing beta
# 49:31.072 outputs PROGRESS Before coordinate slicing beta[40]: {'iter': 1000}
# 49:31.087 outputs PROGRESS After coordinate slicing beta[40]: {'iter': 1000}
# 49:31.098 outputs PROGRESS After index slicing beta: {'iter': 1000}
# 49:31.108 outputs PROGRESS beta: (1, 1, 1, 1, 1, 1000)
# 49:31.124 outputs PROGRESS Slicing log_destination_attraction
# 49:31.134 outputs PROGRESS Before coordinate slicing log_destination_attraction[40]: {'iter': 1000, 'destination': 13}
# 49:31.151 outputs PROGRESS After coordinate slicing log_destination_attraction[40]: {'iter': 1000, 'destination': 13}
# 49:31.162 outputs PROGRESS After index slicing log_destination_attraction: {'destination': 13, 'iter': 1000}
# 49:31.172 outputs PROGRESS log_destination_attraction: (1, 1, 1, 1, 1, 13, 1, 1000)
# Collecting h5 data sequentially:   7%|▋         | 41/600 [00:14<03:13,  2.90it/s]49:31.264 inputs NOTE Loading Harris Wilson data ...
# 49:31.275 inputs NOTE Margins not provided
# 49:31.285 inputs NOTE Cells subset values file not provided
# 49:31.297 outputs NOTE Loading h5 data into xarrays...
# 49:31.351 outputs NOTE Populating data dictionary
# 49:31.368 outputs PROGRESS Slicing alpha
# 49:31.378 outputs PROGRESS Before coordinate slicing alpha[41]: {'iter': 1000}
# 49:31.421 outputs PROGRESS Slicing beta
# 49:31.431 outputs PROGRESS Before coordinate slicing beta[41]: {'iter': 1000}
# 49:31.474 outputs PROGRESS Slicing log_destination_attraction
# 49:31.483 outputs PROGRESS Before coordinate slicing log_destination_attraction[41]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   7%|▋         | 42/600 [00:14<03:11,  2.91it/s]49:31.602 inputs NOTE Loading Harris Wilson data ...
# 49:31.613 inputs NOTE Margins not provided
# 49:31.622 inputs NOTE Cells subset values file not provided
# 49:31.634 outputs NOTE Loading h5 data into xarrays...
# 49:31.688 outputs NOTE Populating data dictionary
# 49:31.704 outputs PROGRESS Slicing alpha
# 49:31.713 outputs PROGRESS Before coordinate slicing alpha[42]: {'iter': 1000}
# 49:31.756 outputs PROGRESS Slicing beta
# 49:31.765 outputs PROGRESS Before coordinate slicing beta[42]: {'iter': 1000}
# 49:31.809 outputs PROGRESS Slicing log_destination_attraction
# 49:31.819 outputs PROGRESS Before coordinate slicing log_destination_attraction[42]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   7%|▋         | 43/600 [00:14<03:10,  2.93it/s]49:31.936 inputs NOTE Loading Harris Wilson data ...
# 49:31.947 inputs NOTE Margins not provided
# 49:31.957 inputs NOTE Cells subset values file not provided
# 49:31.969 outputs NOTE Loading h5 data into xarrays...
# 49:32.023 outputs NOTE Populating data dictionary
# 49:32.039 outputs PROGRESS Slicing alpha
# 49:32.049 outputs PROGRESS Before coordinate slicing alpha[43]: {'iter': 1000}
# 49:32.094 outputs PROGRESS Slicing beta
# 49:32.104 outputs PROGRESS Before coordinate slicing beta[43]: {'iter': 1000}
# 49:32.151 outputs PROGRESS Slicing log_destination_attraction
# 49:32.161 outputs PROGRESS Before coordinate slicing log_destination_attraction[43]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   7%|▋         | 44/600 [00:15<03:10,  2.92it/s]49:32.281 inputs NOTE Loading Harris Wilson data ...
# 49:32.292 inputs NOTE Margins not provided
# 49:32.301 inputs NOTE Cells subset values file not provided
# 49:32.313 outputs NOTE Loading h5 data into xarrays...
# 49:32.367 outputs NOTE Populating data dictionary
# 49:32.382 outputs PROGRESS Slicing alpha
# 49:32.392 outputs PROGRESS Before coordinate slicing alpha[44]: {'iter': 1000}
# 49:32.435 outputs PROGRESS Slicing beta
# 49:32.444 outputs PROGRESS Before coordinate slicing beta[44]: {'iter': 1000}
# 49:32.488 outputs PROGRESS Slicing log_destination_attraction
# 49:32.498 outputs PROGRESS Before coordinate slicing log_destination_attraction[44]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   8%|▊         | 45/600 [00:15<03:08,  2.94it/s]49:32.615 inputs NOTE Loading Harris Wilson data ...
# 49:32.626 inputs NOTE Margins not provided
# 49:32.636 inputs NOTE Cells subset values file not provided
# 49:32.648 outputs NOTE Loading h5 data into xarrays...
# 49:32.701 outputs NOTE Populating data dictionary
# 49:32.717 outputs PROGRESS Slicing alpha
# 49:32.727 outputs PROGRESS Before coordinate slicing alpha[45]: {'iter': 1000}
# 49:32.770 outputs PROGRESS Slicing beta
# 49:32.780 outputs PROGRESS Before coordinate slicing beta[45]: {'iter': 1000}
# 49:32.824 outputs PROGRESS Slicing log_destination_attraction
# 49:32.833 outputs PROGRESS Before coordinate slicing log_destination_attraction[45]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   8%|▊         | 46/600 [00:15<03:07,  2.95it/s]49:32.951 inputs NOTE Loading Harris Wilson data ...
# 49:32.962 inputs NOTE Margins not provided
# 49:32.972 inputs NOTE Cells subset values file not provided
# 49:32.984 outputs NOTE Loading h5 data into xarrays...
# 49:33.037 outputs NOTE Populating data dictionary
# 49:33.055 outputs PROGRESS Slicing alpha
# 49:33.066 outputs PROGRESS Before coordinate slicing alpha[46]: {'iter': 1000}
# 49:33.084 outputs PROGRESS After coordinate slicing alpha[46]: {'iter': 1000}
# 49:33.096 outputs PROGRESS After index slicing alpha: {'iter': 1000}
# 49:33.107 outputs PROGRESS alpha: (1, 1, 1, 1, 1, 1000)
# 49:33.124 outputs PROGRESS Slicing beta
# 49:33.134 outputs PROGRESS Before coordinate slicing beta[46]: {'iter': 1000}
# 49:33.150 outputs PROGRESS After coordinate slicing beta[46]: {'iter': 1000}
# 49:33.161 outputs PROGRESS After index slicing beta: {'iter': 1000}
# 49:33.171 outputs PROGRESS beta: (1, 1, 1, 1, 1, 1000)
# 49:33.187 outputs PROGRESS Slicing log_destination_attraction
# 49:33.197 outputs PROGRESS Before coordinate slicing log_destination_attraction[46]: {'iter': 1000, 'destination': 13}
# 49:33.213 outputs PROGRESS After coordinate slicing log_destination_attraction[46]: {'iter': 1000, 'destination': 13}
# 49:33.225 outputs PROGRESS After index slicing log_destination_attraction: {'destination': 13, 'iter': 1000}
# 49:33.234 outputs PROGRESS log_destination_attraction: (1, 1, 1, 1, 1, 13, 1, 1000)
# Collecting h5 data sequentially:   8%|▊         | 47/600 [00:16<03:12,  2.87it/s]49:33.323 inputs NOTE Loading Harris Wilson data ...
# 49:33.335 inputs NOTE Margins not provided
# 49:33.344 inputs NOTE Cells subset values file not provided
# 49:33.357 outputs NOTE Loading h5 data into xarrays...
# 49:33.411 outputs NOTE Populating data dictionary
# 49:33.427 outputs PROGRESS Slicing alpha
# 49:33.437 outputs PROGRESS Before coordinate slicing alpha[47]: {'iter': 1000}
# 49:33.481 outputs PROGRESS Slicing beta
# 49:33.491 outputs PROGRESS Before coordinate slicing beta[47]: {'iter': 1000}
# 49:33.535 outputs PROGRESS Slicing log_destination_attraction
# 49:33.544 outputs PROGRESS Before coordinate slicing log_destination_attraction[47]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   8%|▊         | 48/600 [00:16<03:10,  2.89it/s]49:33.662 inputs NOTE Loading Harris Wilson data ...
# 49:33.673 inputs NOTE Margins not provided
# 49:33.683 inputs NOTE Cells subset values file not provided
# 49:33.695 outputs NOTE Loading h5 data into xarrays...
# 49:33.748 outputs NOTE Populating data dictionary
# 49:33.764 outputs PROGRESS Slicing alpha
# 49:33.774 outputs PROGRESS Before coordinate slicing alpha[48]: {'iter': 1000}
# 49:33.817 outputs PROGRESS Slicing beta
# 49:33.827 outputs PROGRESS Before coordinate slicing beta[48]: {'iter': 1000}
# 49:33.870 outputs PROGRESS Slicing log_destination_attraction
# 49:33.880 outputs PROGRESS Before coordinate slicing log_destination_attraction[48]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   8%|▊         | 49/600 [00:16<03:08,  2.92it/s]49:33.998 inputs NOTE Loading Harris Wilson data ...
# 49:34.009 inputs NOTE Margins not provided
# 49:34.018 inputs NOTE Cells subset values file not provided
# 49:34.030 outputs NOTE Loading h5 data into xarrays...
# 49:34.083 outputs NOTE Populating data dictionary
# 49:34.099 outputs PROGRESS Slicing alpha
# 49:34.108 outputs PROGRESS Before coordinate slicing alpha[49]: {'iter': 1000}
# 49:34.154 outputs PROGRESS Slicing beta
# 49:34.164 outputs PROGRESS Before coordinate slicing beta[49]: {'iter': 1000}
# 49:34.210 outputs PROGRESS Slicing log_destination_attraction
# 49:34.220 outputs PROGRESS Before coordinate slicing log_destination_attraction[49]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   8%|▊         | 50/600 [00:17<03:08,  2.92it/s]49:34.342 inputs NOTE Loading Harris Wilson data ...
# 49:34.353 inputs NOTE Margins not provided
# 49:34.363 inputs NOTE Cells subset values file not provided
# 49:34.375 outputs NOTE Loading h5 data into xarrays...
# 49:34.428 outputs NOTE Populating data dictionary
# 49:34.444 outputs PROGRESS Slicing alpha
# 49:34.454 outputs PROGRESS Before coordinate slicing alpha[50]: {'iter': 1000}
# 49:34.497 outputs PROGRESS Slicing beta
# 49:34.507 outputs PROGRESS Before coordinate slicing beta[50]: {'iter': 1000}
# 49:34.550 outputs PROGRESS Slicing log_destination_attraction
# 49:34.560 outputs PROGRESS Before coordinate slicing log_destination_attraction[50]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   8%|▊         | 51/600 [00:17<03:07,  2.93it/s]49:34.678 inputs NOTE Loading Harris Wilson data ...
# 49:34.689 inputs NOTE Margins not provided
# 49:34.698 inputs NOTE Cells subset values file not provided
# 49:34.710 outputs NOTE Loading h5 data into xarrays...
# 49:34.763 outputs NOTE Populating data dictionary
# 49:34.779 outputs PROGRESS Slicing alpha
# 49:34.789 outputs PROGRESS Before coordinate slicing alpha[51]: {'iter': 1000}
# 49:34.832 outputs PROGRESS Slicing beta
# 49:34.842 outputs PROGRESS Before coordinate slicing beta[51]: {'iter': 1000}
# 49:34.885 outputs PROGRESS Slicing log_destination_attraction
# 49:34.895 outputs PROGRESS Before coordinate slicing log_destination_attraction[51]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:   9%|▊         | 52/600 [00:17<03:05,  2.95it/s]49:35.013 inputs NOTE Loading Harris Wilson data ...
# 49:35.041 inputs NOTE Margins not provided
# 49:35.061 inputs NOTE Cells subset values file not provided
# 49:35.083 outputs NOTE Loading h5 data into xarrays...
# 49:35.155 outputs NOTE Populating data dictionary
# 49:35.171 outputs PROGRESS Slicing alpha
# 49:35.181 outputs PROGRESS Before coordinate slicing alpha[52]: {'iter': 1000}
# 49:35.197 outputs PROGRESS After coordinate slicing alpha[52]: {'iter': 1000}
# 49:35.208 outputs PROGRESS After index slicing alpha: {'iter': 1000}
# 49:35.218 outputs PROGRESS alpha: (1, 1, 1, 1, 1, 1000)
# 49:35.233 outputs PROGRESS Slicing beta
# 49:35.243 outputs PROGRESS Before coordinate slicing beta[52]: {'iter': 1000}
# 49:35.258 outputs PROGRESS After coordinate slicing beta[52]: {'iter': 1000}
# 49:35.270 outputs PROGRESS After index slicing beta: {'iter': 1000}
# 49:35.279 outputs PROGRESS beta: (1, 1, 1, 1, 1, 1000)
# 49:35.295 outputs PROGRESS Slicing log_destination_attraction
# 49:35.305 outputs PROGRESS Before coordinate slicing log_destination_attraction[52]: {'iter': 1000, 'destination': 13}
# 49:35.321 outputs PROGRESS After coordinate slicing log_destination_attraction[52]: {'iter': 1000, 'destination': 13}
# 49:35.333 outputs PROGRESS After index slicing log_destination_attraction: {'destination': 13, 'iter': 1000}
# 49:35.342 outputs PROGRESS log_destination_attraction: (1, 1, 1, 1, 1, 13, 1, 1000)
# Collecting h5 data sequentially:   9%|▉         | 53/600 [00:18<03:18,  2.76it/s]49:35.433 inputs NOTE Loading Harris Wilson data ...
# 49:35.444 inputs NOTE Margins not provided
# 49:35.453 inputs NOTE Cells subset values file not provided
# ...
# 52:41.635 inputs NOTE Cells subset values file not provided
# 52:41.647 outputs NOTE Loading h5 data into xarrays...
# 52:41.700 outputs NOTE Populating data dictionary
# 52:41.717 outputs PROGRESS Slicing alpha
# 52:41.727 outputs PROGRESS Before coordinate slicing alpha[582]: {'iter': 1000}
# 52:41.770 outputs PROGRESS Slicing beta
# 52:41.780 outputs PROGRESS Before coordinate slicing beta[582]: {'iter': 1000}
# 52:41.825 outputs PROGRESS Slicing log_destination_attraction
# 52:41.835 outputs PROGRESS Before coordinate slicing log_destination_attraction[582]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:  97%|█████████▋| 583/600 [03:24<00:05,  2.87it/s]52:41.956 inputs NOTE Loading Harris Wilson data ...
# 52:41.967 inputs NOTE Margins not provided
# 52:41.977 inputs NOTE Cells subset values file not provided
# 52:41.989 outputs NOTE Loading h5 data into xarrays...
# 52:42.044 outputs NOTE Populating data dictionary
# 52:42.061 outputs PROGRESS Slicing alpha
# 52:42.071 outputs PROGRESS Before coordinate slicing alpha[583]: {'iter': 1000}
# 52:42.118 outputs PROGRESS Slicing beta
# 52:42.128 outputs PROGRESS Before coordinate slicing beta[583]: {'iter': 1000}
# 52:42.177 outputs PROGRESS Slicing log_destination_attraction
# 52:42.186 outputs PROGRESS Before coordinate slicing log_destination_attraction[583]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:  97%|█████████▋| 584/600 [03:25<00:05,  2.85it/s]52:42.312 inputs NOTE Loading Harris Wilson data ...
# 52:42.324 inputs NOTE Margins not provided
# 52:42.334 inputs NOTE Cells subset values file not provided
# 52:42.347 outputs NOTE Loading h5 data into xarrays...
# 52:42.401 outputs NOTE Populating data dictionary
# 52:42.417 outputs PROGRESS Slicing alpha
# 52:42.427 outputs PROGRESS Before coordinate slicing alpha[584]: {'iter': 1000}
# 52:42.471 outputs PROGRESS Slicing beta
# 52:42.481 outputs PROGRESS Before coordinate slicing beta[584]: {'iter': 1000}
# 52:42.526 outputs PROGRESS Slicing log_destination_attraction
# 52:42.535 outputs PROGRESS Before coordinate slicing log_destination_attraction[584]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:  98%|█████████▊| 585/600 [03:25<00:05,  2.87it/s]52:42.657 inputs NOTE Loading Harris Wilson data ...
# 52:42.669 inputs NOTE Margins not provided
# 52:42.679 inputs NOTE Cells subset values file not provided
# 52:42.691 outputs NOTE Loading h5 data into xarrays...
# 52:42.746 outputs NOTE Populating data dictionary
# 52:42.762 outputs PROGRESS Slicing alpha
# 52:42.772 outputs PROGRESS Before coordinate slicing alpha[585]: {'iter': 1000}
# 52:42.817 outputs PROGRESS Slicing beta
# 52:42.827 outputs PROGRESS Before coordinate slicing beta[585]: {'iter': 1000}
# 52:42.871 outputs PROGRESS Slicing log_destination_attraction
# 52:42.881 outputs PROGRESS Before coordinate slicing log_destination_attraction[585]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:  98%|█████████▊| 586/600 [03:25<00:04,  2.87it/s]52:43.002 inputs NOTE Loading Harris Wilson data ...
# 52:43.014 inputs NOTE Margins not provided
# 52:43.024 inputs NOTE Cells subset values file not provided
# 52:43.036 outputs NOTE Loading h5 data into xarrays...
# 52:43.091 outputs NOTE Populating data dictionary
# 52:43.107 outputs PROGRESS Slicing alpha
# 52:43.117 outputs PROGRESS Before coordinate slicing alpha[586]: {'iter': 1000}
# 52:43.133 outputs PROGRESS After coordinate slicing alpha[586]: {'iter': 1000}
# 52:43.144 outputs PROGRESS After index slicing alpha: {'iter': 1000}
# 52:43.154 outputs PROGRESS alpha: (1, 1, 1, 1, 1, 1000)
# 52:43.170 outputs PROGRESS Slicing beta
# 52:43.180 outputs PROGRESS Before coordinate slicing beta[586]: {'iter': 1000}
# 52:43.196 outputs PROGRESS After coordinate slicing beta[586]: {'iter': 1000}
# 52:43.207 outputs PROGRESS After index slicing beta: {'iter': 1000}
# 52:43.217 outputs PROGRESS beta: (1, 1, 1, 1, 1, 1000)
# 52:43.234 outputs PROGRESS Slicing log_destination_attraction
# 52:43.244 outputs PROGRESS Before coordinate slicing log_destination_attraction[586]: {'iter': 1000, 'destination': 13}
# 52:43.261 outputs PROGRESS After coordinate slicing log_destination_attraction[586]: {'iter': 1000, 'destination': 13}
# 52:43.274 outputs PROGRESS After index slicing log_destination_attraction: {'destination': 13, 'iter': 1000}
# 52:43.284 outputs PROGRESS log_destination_attraction: (1, 1, 1, 1, 1, 13, 1, 1000)
# Collecting h5 data sequentially:  98%|█████████▊| 587/600 [03:26<00:04,  2.81it/s]52:43.379 inputs NOTE Loading Harris Wilson data ...
# 52:43.390 inputs NOTE Margins not provided
# 52:43.400 inputs NOTE Cells subset values file not provided
# 52:43.413 outputs NOTE Loading h5 data into xarrays...
# 52:43.468 outputs NOTE Populating data dictionary
# 52:43.485 outputs PROGRESS Slicing alpha
# 52:43.495 outputs PROGRESS Before coordinate slicing alpha[587]: {'iter': 1000}
# 52:43.539 outputs PROGRESS Slicing beta
# 52:43.549 outputs PROGRESS Before coordinate slicing beta[587]: {'iter': 1000}
# 52:43.594 outputs PROGRESS Slicing log_destination_attraction
# 52:43.604 outputs PROGRESS Before coordinate slicing log_destination_attraction[587]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:  98%|█████████▊| 588/600 [03:26<00:04,  2.83it/s]52:43.727 inputs NOTE Loading Harris Wilson data ...
# 52:43.739 inputs NOTE Margins not provided
# 52:43.748 inputs NOTE Cells subset values file not provided
# 52:43.761 outputs NOTE Loading h5 data into xarrays...
# 52:43.816 outputs NOTE Populating data dictionary
# 52:43.833 outputs PROGRESS Slicing alpha
# 52:43.843 outputs PROGRESS Before coordinate slicing alpha[588]: {'iter': 1000}
# 52:43.888 outputs PROGRESS Slicing beta
# 52:43.898 outputs PROGRESS Before coordinate slicing beta[588]: {'iter': 1000}
# 52:43.947 outputs PROGRESS Slicing log_destination_attraction
# 52:43.957 outputs PROGRESS Before coordinate slicing log_destination_attraction[588]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:  98%|█████████▊| 589/600 [03:26<00:03,  2.83it/s]52:44.084 inputs NOTE Loading Harris Wilson data ...
# 52:44.096 inputs NOTE Margins not provided
# 52:44.106 inputs NOTE Cells subset values file not provided
# 52:44.118 outputs NOTE Loading h5 data into xarrays...
# 52:44.174 outputs NOTE Populating data dictionary
# 52:44.191 outputs PROGRESS Slicing alpha
# 52:44.201 outputs PROGRESS Before coordinate slicing alpha[589]: {'iter': 1000}
# 52:44.250 outputs PROGRESS Slicing beta
# 52:44.260 outputs PROGRESS Before coordinate slicing beta[589]: {'iter': 1000}
# 52:44.309 outputs PROGRESS Slicing log_destination_attraction
# 52:44.320 outputs PROGRESS Before coordinate slicing log_destination_attraction[589]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:  98%|█████████▊| 590/600 [03:27<00:03,  2.80it/s]52:44.447 inputs NOTE Loading Harris Wilson data ...
# 52:44.459 inputs NOTE Margins not provided
# 52:44.468 inputs NOTE Cells subset values file not provided
# 52:44.481 outputs NOTE Loading h5 data into xarrays...
# 52:44.536 outputs NOTE Populating data dictionary
# 52:44.553 outputs PROGRESS Slicing alpha
# 52:44.563 outputs PROGRESS Before coordinate slicing alpha[590]: {'iter': 1000}
# 52:44.607 outputs PROGRESS Slicing beta
# 52:44.617 outputs PROGRESS Before coordinate slicing beta[590]: {'iter': 1000}
# 52:44.662 outputs PROGRESS Slicing log_destination_attraction
# 52:44.672 outputs PROGRESS Before coordinate slicing log_destination_attraction[590]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:  98%|█████████▊| 591/600 [03:27<00:03,  2.82it/s]52:44.794 inputs NOTE Loading Harris Wilson data ...
# 52:44.805 inputs NOTE Margins not provided
# 52:44.815 inputs NOTE Cells subset values file not provided
# 52:44.828 outputs NOTE Loading h5 data into xarrays...
# 52:44.883 outputs NOTE Populating data dictionary
# 52:44.900 outputs PROGRESS Slicing alpha
# 52:44.910 outputs PROGRESS Before coordinate slicing alpha[591]: {'iter': 1000}
# 52:44.954 outputs PROGRESS Slicing beta
# 52:44.964 outputs PROGRESS Before coordinate slicing beta[591]: {'iter': 1000}
# 52:45.008 outputs PROGRESS Slicing log_destination_attraction
# 52:45.018 outputs PROGRESS Before coordinate slicing log_destination_attraction[591]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:  99%|█████████▊| 592/600 [03:28<00:02,  2.84it/s]52:45.140 inputs NOTE Loading Harris Wilson data ...
# 52:45.151 inputs NOTE Margins not provided
# 52:45.161 inputs NOTE Cells subset values file not provided
# 52:45.173 outputs NOTE Loading h5 data into xarrays...
# 52:45.228 outputs NOTE Populating data dictionary
# 52:45.244 outputs PROGRESS Slicing alpha
# 52:45.254 outputs PROGRESS Before coordinate slicing alpha[592]: {'iter': 1000}
# 52:45.269 outputs PROGRESS After coordinate slicing alpha[592]: {'iter': 1000}
# 52:45.281 outputs PROGRESS After index slicing alpha: {'iter': 1000}
# 52:45.290 outputs PROGRESS alpha: (1, 1, 1, 1, 1, 1000)
# 52:45.306 outputs PROGRESS Slicing beta
# 52:45.315 outputs PROGRESS Before coordinate slicing beta[592]: {'iter': 1000}
# 52:45.331 outputs PROGRESS After coordinate slicing beta[592]: {'iter': 1000}
# 52:45.342 outputs PROGRESS After index slicing beta: {'iter': 1000}
# 52:45.351 outputs PROGRESS beta: (1, 1, 1, 1, 1, 1000)
# 52:45.368 outputs PROGRESS Slicing log_destination_attraction
# 52:45.377 outputs PROGRESS Before coordinate slicing log_destination_attraction[592]: {'iter': 1000, 'destination': 13}
# 52:45.394 outputs PROGRESS After coordinate slicing log_destination_attraction[592]: {'iter': 1000, 'destination': 13}
# 52:45.405 outputs PROGRESS After index slicing log_destination_attraction: {'destination': 13, 'iter': 1000}
# 52:45.415 outputs PROGRESS log_destination_attraction: (1, 1, 1, 1, 1, 13, 1, 1000)
# Collecting h5 data sequentially:  99%|█████████▉| 593/600 [03:28<00:02,  2.80it/s]52:45.505 inputs NOTE Loading Harris Wilson data ...
# 52:45.516 inputs NOTE Margins not provided
# 52:45.526 inputs NOTE Cells subset values file not provided
# 52:45.538 outputs NOTE Loading h5 data into xarrays...
# 52:45.592 outputs NOTE Populating data dictionary
# 52:45.608 outputs PROGRESS Slicing alpha
# 52:45.618 outputs PROGRESS Before coordinate slicing alpha[593]: {'iter': 1000}
# 52:45.661 outputs PROGRESS Slicing beta
# 52:45.671 outputs PROGRESS Before coordinate slicing beta[593]: {'iter': 1000}
# 52:45.714 outputs PROGRESS Slicing log_destination_attraction
# 52:45.723 outputs PROGRESS Before coordinate slicing log_destination_attraction[593]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:  99%|█████████▉| 594/600 [03:28<00:02,  2.85it/s]52:45.845 inputs NOTE Loading Harris Wilson data ...
# 52:45.857 inputs NOTE Margins not provided
# 52:45.867 inputs NOTE Cells subset values file not provided
# 52:45.879 outputs NOTE Loading h5 data into xarrays...
# 52:45.933 outputs NOTE Populating data dictionary
# 52:45.950 outputs PROGRESS Slicing alpha
# 52:45.959 outputs PROGRESS Before coordinate slicing alpha[594]: {'iter': 1000}
# 52:46.003 outputs PROGRESS Slicing beta
# 52:46.012 outputs PROGRESS Before coordinate slicing beta[594]: {'iter': 1000}
# 52:46.056 outputs PROGRESS Slicing log_destination_attraction
# 52:46.066 outputs PROGRESS Before coordinate slicing log_destination_attraction[594]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:  99%|█████████▉| 595/600 [03:29<00:01,  2.87it/s]52:46.323 inputs NOTE Loading Harris Wilson data ...
# 52:46.335 inputs NOTE Margins not provided
# 52:46.344 inputs NOTE Cells subset values file not provided
# 52:46.356 outputs NOTE Loading h5 data into xarrays...
# 52:46.410 outputs NOTE Populating data dictionary
# 52:46.426 outputs PROGRESS Slicing alpha
# 52:46.435 outputs PROGRESS Before coordinate slicing alpha[595]: {'iter': 1000}
# 52:46.482 outputs PROGRESS Slicing beta
# 52:46.491 outputs PROGRESS Before coordinate slicing beta[595]: {'iter': 1000}
# 52:46.538 outputs PROGRESS Slicing log_destination_attraction
# 52:46.548 outputs PROGRESS Before coordinate slicing log_destination_attraction[595]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially:  99%|█████████▉| 596/600 [03:29<00:01,  2.57it/s]52:46.669 inputs NOTE Loading Harris Wilson data ...
# 52:46.680 inputs NOTE Margins not provided
# 52:46.690 inputs NOTE Cells subset values file not provided
# 52:46.702 outputs NOTE Loading h5 data into xarrays...
# 52:46.756 outputs NOTE Populating data dictionary
# 52:46.772 outputs PROGRESS Slicing alpha
# 52:46.781 outputs PROGRESS Before coordinate slicing alpha[596]: {'iter': 1000}
# 52:46.824 outputs PROGRESS Slicing beta
# 52:46.834 outputs PROGRESS Before coordinate slicing beta[596]: {'iter': 1000}
# 52:46.879 outputs PROGRESS Slicing log_destination_attraction
# 52:46.889 outputs PROGRESS Before coordinate slicing log_destination_attraction[596]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially: 100%|█████████▉| 597/600 [03:29<00:01,  2.67it/s]52:47.009 inputs NOTE Loading Harris Wilson data ...
# 52:47.020 inputs NOTE Margins not provided
# 52:47.030 inputs NOTE Cells subset values file not provided
# 52:47.042 outputs NOTE Loading h5 data into xarrays...
# 52:47.095 outputs NOTE Populating data dictionary
# 52:47.112 outputs PROGRESS Slicing alpha
# 52:47.122 outputs PROGRESS Before coordinate slicing alpha[597]: {'iter': 1000}
# 52:47.165 outputs PROGRESS Slicing beta
# 52:47.174 outputs PROGRESS Before coordinate slicing beta[597]: {'iter': 1000}
# 52:47.218 outputs PROGRESS Slicing log_destination_attraction
# 52:47.227 outputs PROGRESS Before coordinate slicing log_destination_attraction[597]: {'iter': 1000, 'destination': 13}
# Collecting h5 data sequentially: 100%|█████████▉| 598/600 [03:30<00:00,  2.75it/s]52:47.345 inputs NOTE Loading Harris Wilson data ...
# 52:47.356 inputs NOTE Margins not provided
# 52:47.366 inputs NOTE Cells subset values file not provided
# 52:47.378 outputs NOTE Loading h5 data into xarrays...
# 52:47.431 outputs NOTE Populating data dictionary
# 52:47.448 outputs PROGRESS Slicing alpha
# 52:47.457 outputs PROGRESS Before coordinate slicing alpha[598]: {'iter': 1000}
# 52:47.473 outputs PROGRESS After coordinate slicing alpha[598]: {'iter': 1000}
# 52:47.483 outputs PROGRESS After index slicing alpha: {'iter': 1000}
# 52:47.493 outputs PROGRESS alpha: (1, 1, 1, 1, 1, 1000)
# 52:47.509 outputs PROGRESS Slicing beta
# 52:47.518 outputs PROGRESS Before coordinate slicing beta[598]: {'iter': 1000}
# 52:47.534 outputs PROGRESS After coordinate slicing beta[598]: {'iter': 1000}
# 52:47.545 outputs PROGRESS After index slicing beta: {'iter': 1000}
# 52:47.555 outputs PROGRESS beta: (1, 1, 1, 1, 1, 1000)
# 52:47.571 outputs PROGRESS Slicing log_destination_attraction
# 52:47.580 outputs PROGRESS Before coordinate slicing log_destination_attraction[598]: {'iter': 1000, 'destination': 13}
# 52:47.597 outputs PROGRESS After coordinate slicing log_destination_attraction[598]: {'iter': 1000, 'destination': 13}
# 52:47.608 outputs PROGRESS After index slicing log_destination_attraction: {'destination': 13, 'iter': 1000}
# 52:47.618 outputs PROGRESS log_destination_attraction: (1, 1, 1, 1, 1, 13, 1, 1000)
# Collecting h5 data sequentially: 100%|█████████▉| 599/600 [03:30<00:00,  2.76it/s]52:47.707 inputs NOTE Loading Harris Wilson data ...
# 52:47.719 inputs NOTE Margins not provided
# 52:47.728 inputs NOTE Cells subset values file not provided
# 52:47.740 outputs NOTE Loading h5 data into xarrays...
# 52:47.794 outputs NOTE Populating data dictionary
# 52:47.810 outputs PROGRESS Slicing alpha
# 52:47.820 outputs PROGRESS Before coordinate slicing alpha[599]: {'iter': 1000}
# 52:47.864 outputs PROGRESS Slicing beta
# 52:47.874 outputs PROGRESS Before coordinate slicing beta[599]: {'iter': 1000}
# 52:47.919 outputs PROGRESS Slicing log_destination_attraction
# 52:47.929 outputs PROGRESS Before coordinate slicing log_destination_attraction[599]: {'iter': 1000, 'destination': 13}
# 52:47.970 outputs INFO Creating xarray(s) for alpha, beta, log_destination_attraction.
# 52:49.551 outputs INFO Wrote output collection to ../../data/outputs/cambridge/exp1/SIM_NN_SweepedNoise_05_12_2023_21_23_00/sample_collections

# %%
inputs = Inputs(
    config = simnn_outputs.config,
    synthetic_data = False,
    logger = simnn_outputs.logger
)
inputs.cast_to_xarray()
ground_truth_table = inputs.data.ground_truth_table
# Out:
# 52:49.776 inputs NOTE Loading Harris Wilson data ...
# 52:49.797 inputs NOTE Margins not provided
# 52:49.812 inputs NOTE Cells subset values file not provided

# %%
simnn_intensity = simnn_outputs.get_sample("intensity")
simnn_intensity_mean = simnn_intensity.mean(dim=['iter','seed'],dtype='float64')
simnn_intensity_flat = simnn_intensity.stack(id=['iter','seed'])
simnn_intensity_cp = coverage_probability(deepcopy(simnn_intensity_flat),ground_truth_table,dim='id')
sim_nn_residual = (ground_truth_table-simnn_intensity_mean).squeeze('sweep')
sim_nn_residual_demand = sim_nn_residual.sum('origin',dtype='float64')
# Out:
# 52:49.877 inputs NOTE Loading Harris Wilson data ...
# 52:49.894 inputs NOTE Margins not provided
# 52:49.907 inputs NOTE Cells subset values file not provided
# 52:49.983 outputs PROGRESS Loaded cost_matrix sample
# 52:50.006 outputs PROGRESS Loaded origin_demand sample
# 52:50.027 outputs PROGRESS Loaded grand_total sample
# 52:50.048 __init__ PROGRESS Building
#             69x13 ProductionConstrained Spatial Interaction Model
#             Origin demand sum: 0.9999999403953552
#             Destination demand sum: None
#             Origin attraction sum: None
#             Destination attraction sum: None
#             Cost matrix sum: 358.17156982421875
#             Alpha: 1.0
#             Beta: 1.0
#             Beta scaling: None
#
# 52:50.066 outputs PROGRESS Loaded alpha sample
# 52:50.083 outputs PROGRESS Loaded log_destination_attraction sample
# 52:50.543 outputs PROGRESS Loaded intensity sample

# %%
print(simnn_intensity.sweep.values)
# Out:
# [(0.14142000675201416, "['alpha', 'beta']", '_row_constrained', 'ProductionConstrained')]

# %%
sim_nn_residual.values.min(),sim_nn_residual.values.max()
# Out:
# (-75.01730598461151, 144.96222004364012)

# %% [markdown]
# ## SIM_MCMC

# %%
sim_mcmc_experiment_id = "SIM_MCMC_SweepedNoise_16_05_2023_20_09_04"
# Specify experiment group id
experiment_group_id = 'exp1/'
dataset = 'cambridge'
sim_mcmc_experiment_dir = f'../../data/outputs/{dataset}/{experiment_group_id}/{sim_mcmc_experiment_id}/'
sim_mcmc_relative_experiment_dir = os.path.relpath(sim_mcmc_experiment_dir,os.getcwd())

# %%
sim_mcmc_settings = {
    "logging_mode": "INFO",
    "coordinate_slice": [
        "da.sigma==0.14142",
        "da.title=='_row_constrained'"
    ],
    "slice":True,
    "metadata_keys":[],
    "burnin_thinning_trimming": [{'iter': {"burnin":0, "thinning":1, "trimming":10000000}}],
    "sample":["intensity"],
    "group_by":[],
    "evaluation_kwargs":['intensity'],
    "filename_ending":"test",
    "force_reload":False,
    "n_workers": 1
}

# %%
# Initialise outputs
sim_mcmc_outputs = Outputs(
    config = os.path.join(sim_mcmc_relative_experiment_dir,"config.json"),
    settings = sim_mcmc_settings,
    inputs = None,
    slice = True,
    level = 'NOTE'
)
# Silence outputs
sim_mcmc_outputs.logger.setLevels(console_level='NOTE')
# Load all data
sim_mcmc_outputs.load()

# Get data from first sweep of the SIM_MCMC experiment
sim_mcmc_outputs = sim_mcmc_outputs.get(0)
# Out:
# 52:53.054 config INFO ----------------------------------------------------------------------------------
# 52:53.065 config INFO Parameter space size:
#  --- title: ['title', 'name'] (2)
#  --- sigma: ['sigma', 'to_learn', 'covariance'] (2)
# 52:53.076 config INFO Total = 4.
# 52:53.086 config INFO ----------------------------------------------------------------------------------
# 52:53.126 outputs INFO //////////////////////////////////////////////////////////////////////////////////
# 52:53.136 outputs INFO Slicing coordinates:
# 52:53.146 outputs INFO sigma==0.14142
# 52:53.156 outputs INFO title=='_row_constrained'
# 52:53.166 outputs INFO iter: burnin = 0, thinning = 1, trimming = 10000000
# 52:53.176 outputs INFO //////////////////////////////////////////////////////////////////////////////////
# 52:53.186 outputs INFO Reading samples alpha, beta, log_destination_attraction, sign.
# Reading alpha,beta,log_destination_attraction,sign group data:   0%|          | 0/4 [00:00<?, ?it/s]52:53.214 outputs WARNING Slicing alpha {'sigma': 1, 'to_learn': 1, 'covariance': 1, 'title': 1, 'name': 1, 'iter': 100000} which has already been potentially sliced.
# 52:53.224 outputs PROGRESS Slicing alpha
# 52:53.234 outputs PROGRESS Before coordinate slicing alpha[0]: {'iter': 100000}
# 52:53.251 outputs PROGRESS After coordinate slicing alpha[0]: {'iter': 100000}
# 52:53.267 outputs PROGRESS After index slicing alpha: {'iter': 100000}
# 52:53.283 outputs WARNING Slicing beta {'sigma': 1, 'to_learn': 1, 'covariance': 1, 'title': 1, 'name': 1, 'iter': 100000} which has already been potentially sliced.
# 52:53.294 outputs PROGRESS Slicing beta
# 52:53.304 outputs PROGRESS Before coordinate slicing beta[0]: {'iter': 100000}
# 52:53.320 outputs PROGRESS After coordinate slicing beta[0]: {'iter': 100000}
# 52:53.336 outputs PROGRESS After index slicing beta: {'iter': 100000}
# Reading alpha,beta,log_destination_attraction,sign group data:  50%|█████     | 2/4 [00:00<00:00, 13.37it/s]52:53.356 outputs WARNING Slicing log_destination_attraction {'sigma': 1, 'to_learn': 1, 'covariance': 1, 'title': 1, 'name': 1, 'destination': 13, 'time': 1, 'iter': 100000} which has already been potentially sliced.
# 52:53.366 outputs PROGRESS Slicing log_destination_attraction
# 52:53.376 outputs PROGRESS Before coordinate slicing log_destination_attraction[0]: {'destination': 13, 'iter': 100000}
# 52:53.400 outputs PROGRESS After coordinate slicing log_destination_attraction[0]: {'destination': 13, 'iter': 100000}
# 52:53.419 outputs PROGRESS After index slicing log_destination_attraction: {'destination': 13, 'iter': 100000}
# 52:53.437 outputs WARNING Slicing sign {'sigma': 1, 'to_learn': 1, 'covariance': 1, 'title': 1, 'name': 1, 'iter': 100000} which has already been potentially sliced.
# 52:53.447 outputs PROGRESS Slicing sign
# 52:53.457 outputs PROGRESS Before coordinate slicing sign[0]: {'iter': 100000}
# 52:53.474 outputs PROGRESS After coordinate slicing sign[0]: {'iter': 100000}
# 52:53.490 outputs PROGRESS After index slicing sign: {'iter': 100000}
# 52:53.503 outputs INFO Creating Data Collection for each group.
# Grouping/Initialising Data Collection samples sequentially: 100%|██████████| 4/4 [00:00<00:00, 41527.76it/s]
# Combining Data Collection group elements: 100%|██████████| 1/1 [00:00<00:00, 26379.27it/s]
# Combining Data Collection group elements: 100%|██████████| 1/1 [00:00<00:00, 26379.27it/s]
# Combining Data Collection group elements: 100%|██████████| 1/1 [00:00<00:00, 28339.89it/s]
# Combining Data Collection group elements: 100%|██████████| 1/1 [00:00<00:00, 21959.71it/s]

# %%
sim_mcmc_intensity = sim_mcmc_outputs.get_sample("intensity")
sim_mcmc_intensity_mean = sim_mcmc_intensity.mean(dim=['iter'],dtype='float64')
sim_mcmc_residual = (ground_truth_table-sim_mcmc_intensity_mean).squeeze('sweep')
sim_mcmc_residual_demand = sim_mcmc_residual.sum('origin',dtype='float64')
sim_mcmc_intensity_cp = coverage_probability(deepcopy(sim_mcmc_intensity),ground_truth_table,dim='iter')
# Out:
# 52:53.605 inputs NOTE Loading Harris Wilson data ...
# 52:53.620 inputs NOTE Margins not provided
# 52:53.631 inputs NOTE Cells subset values file not provided
# 52:53.665 outputs PROGRESS Loaded cost_matrix sample
# 52:53.676 outputs PROGRESS Loaded origin_demand sample
# 52:53.686 outputs PROGRESS Loaded grand_total sample
# 52:53.696 __init__ PROGRESS Building
#             69x13 ProductionConstrained Spatial Interaction Model
#             Origin demand sum: 0.9999999403953552
#             Destination demand sum: None
#             Origin attraction sum: None
#             Destination attraction sum: None
#             Cost matrix sum: 1.0
#             Alpha: 0.5
#             Beta: 0.5
#             Beta scaling: None
#
# 52:53.707 outputs PROGRESS Loaded alpha sample
# 52:53.717 outputs PROGRESS Loaded log_destination_attraction sample
# 52:54.156 outputs PROGRESS Loaded intensity sample

# %%
sim_mcmc_residual.sweep.values
# Out:
# array((0.14142000675201416, "['alpha', 'beta']", '[[1.0, 0.0], [0.0, 1.0]]', '_row_constrained', 'ProductionConstrained'),
#       dtype=object)

# %% [markdown]
# ## SIT_MCMC

# %%
# Specify experiment id
sit_mcmc_experiment_id = "JointTableSIM_MCMC_SweepedNoise_16_05_2023_20_09_04"
# Specify experiment group id
experiment_group_id = 'exp1/'
dataset = 'cambridge'
sit_mcmc_experiment_dir = f'../../data/outputs/{dataset}/{experiment_group_id}/{sit_mcmc_experiment_id}/'
sit_mcmc_relative_experiment_dir = os.path.relpath(sit_mcmc_experiment_dir,os.getcwd())

sit_mcmc_settings = {
    "logging_mode": "INFO",
    "coordinate_slice": [
        "da.sigma==0.14142",
        "da.title=='_row_constrained'"
    ],
    "slice":True,
    "metadata_keys":[],
    "burnin_thinning_trimming": [{'iter': {"burnin":0, "thinning":1, "trimming":10000000}}],
    "sample":["table"],
    "group_by":[],
    "evaluation_kwargs":['table'],
    "filename_ending":"test",
    "force_reload":False,
    "n_workers": 1
}

# %%
# Initialise outputs
sit_mcmc_outputs = Outputs(
    config = os.path.join(sit_mcmc_relative_experiment_dir,"config.json"),
    settings = sit_mcmc_settings,
    inputs = None,
    slice = True,
    level = 'NOTE'
)
# Silence outputs
sit_mcmc_outputs.logger.setLevels(console_level='NOTE')
# Load all data
sit_mcmc_outputs.load()
sit_mcmc_outputs = sit_mcmc_outputs.get(0)
# Out:
# 52:57.129 config INFO ----------------------------------------------------------------------------------
# 52:57.138 config INFO Parameter space size:
#  --- title: ['title', 'axes', 'cells', 'name', 'proposal'] (7)
#  --- sigma: ['sigma', 'to_learn', 'covariance'] (2)
# 52:57.148 config INFO Total = 14.
# 52:57.158 config INFO ----------------------------------------------------------------------------------
# 52:57.198 outputs INFO //////////////////////////////////////////////////////////////////////////////////
# 52:57.208 outputs INFO Slicing coordinates:
# 52:57.218 outputs INFO sigma==0.14142
# 52:57.227 outputs INFO title=='_row_constrained'
# 52:57.237 outputs INFO iter: burnin = 0, thinning = 1, trimming = 10000000
# 52:57.247 outputs INFO //////////////////////////////////////////////////////////////////////////////////
# 52:57.258 outputs INFO Reading samples table.
# Reading table group data:   0%|          | 0/1 [00:00<?, ?it/s]52:57.378 outputs WARNING Slicing table {'sigma': 1, 'to_learn': 1, 'covariance': 1, 'title': 1, 'axes': 1, 'cells': 1, 'name': 1, 'proposal': 1, 'origin': 69, 'destination': 13, 'iter': 100000} which has already been potentially sliced.
# 52:57.498 outputs PROGRESS Slicing table
# 52:57.508 outputs PROGRESS Before coordinate slicing table[0]: {'origin': 69, 'destination': 13, 'iter': 100000}
# 52:58.195 outputs PROGRESS After coordinate slicing table[0]: {'origin': 69, 'destination': 13, 'iter': 100000}
# 52:58.455 outputs PROGRESS After index slicing table: {'origin': 69, 'destination': 13, 'iter': 100000}
# 52:58.582 outputs INFO Creating Data Collection for each group.
# Grouping/Initialising Data Collection samples sequentially: 100%|██████████| 1/1 [00:00<00:00, 16256.99it/s]
# Combining Data Collection group elements: 100%|██████████| 1/1 [00:00<00:00, 25575.02it/s]

# %%
# Get data from first sweep of the JointTableSIM_MCMC experiment
sit_mcmc_table = sit_mcmc_outputs.get_sample("table")
sit_mcmc_table_mean = sit_mcmc_table.mean(dim=['iter'],dtype='float64')
sit_mcmc_residual = (ground_truth_table-sit_mcmc_table_mean).squeeze('sweep')
sit_mcmc_residual_demand = sit_mcmc_residual.sum('origin',dtype='float64')
sit_mcmc_table_cp = coverage_probability(deepcopy(sit_mcmc_table),ground_truth_table,dim='iter')
# Out:
# 52:58.870 inputs NOTE Loading Harris Wilson data ...
# 52:58.882 inputs NOTE Margins not provided
# 52:58.892 inputs NOTE Cells subset values file not provided
# 52:58.903 outputs PROGRESS Loaded table sample

# %%
sit_mcmc_residual.sweep.values
# Out:
# array((0.14142000675201416, "['alpha', 'beta']", '[[1.0, 0.0], [0.0, 1.0]]', '_row_constrained', '[[1]]', 'None', 'ProductionConstrained', 'direct_sampling'),
#       dtype=object)

# %% [markdown]
# ## All three methods

# %%
print(sim_mcmc_residual.values.min(),sim_mcmc_residual.values.max())
print(
    "SIM MCMC \n",
    "SRMSE",srmse(sim_mcmc_intensity_mean,ground_truth_table).values[0], 
    "CP",sim_mcmc_intensity_cp.mean(['origin','destination'],dtype='float64').values[0]
)
# Out:
# -119.0084510760498 290.6952456342316
# SIM MCMC
#  SRMSE 0.6195762415103968 CP 0.31438127090301005

# %%
print(sit_mcmc_residual.values.min(),sit_mcmc_residual.values.max())
print(
    "Joint Table SIM MCMC \n",
    "SRMSE",srmse(sit_mcmc_table_mean,ground_truth_table).values[0],
    "CP",sit_mcmc_table_cp.mean(['origin','destination'],dtype='float64').values[0]
)
# Out:
# -122.04723999999999 291.41227000000003
# Joint Table SIM MCMC
#  SRMSE 0.615262826311941 CP 0.5797101449275363

# %%
print(sim_nn_residual.values.min(),sim_nn_residual.values.max())
print(
    "SIM NN \n",
    "SRMSE",srmse(simnn_intensity_mean,ground_truth_table).values[0],
    "CP",simnn_intensity_cp.mean(['origin','destination'],dtype='float64').values[0]
)
# Out:
# -75.01730598461151 144.96222004364012
# SIM NN
#  SRMSE 0.415653454189442 CP 0.9208472686733556

# %%
ZERO_COLOR = 0.2954

# %%
FLOW_MIN_VAL = min(sim_mcmc_residual.values.min(),sim_nn_residual.values.min(),sit_mcmc_residual.values.min())
FLOW_MAX_VAL = max(sim_mcmc_residual.values.max(),sim_nn_residual.values.max(),sit_mcmc_residual.values.max())
print(FLOW_MIN_VAL,FLOW_MAX_VAL)
# Out:
# -122.04723999999999 291.41227000000003

# %%
DEMAND_MIN_VAL = min(
    sim_mcmc_residual.sum('origin',dtype='float64').values.min(),
    sim_nn_residual.sum('origin',dtype='float64').values.min(),
    sit_mcmc_residual.sum('origin',dtype='float64').values.min()
)
DEMAND_MAX_VAL = max(
    sim_mcmc_residual.sum('origin',dtype='float64').values.max(),
    sim_nn_residual.sum('origin',dtype='float64').values.max(),
    sit_mcmc_residual.sum('origin',dtype='float64').values.max()
)
print(DEMAND_MIN_VAL,DEMAND_MAX_VAL)
# Out:
# -961.2746893793677 1217.6436098052407

# %%
def normalise_to_flow_colorscale(value):
    return (value - FLOW_MIN_VAL) / (FLOW_MAX_VAL - FLOW_MIN_VAL)
def normalise_to_demand_colorscale(value):
    return (value - DEMAND_MIN_VAL) / (DEMAND_MAX_VAL - DEMAND_MIN_VAL)

def write_mixed_numpy_to_dat(filename: str, array: np.ndarray, header: list[str] = None, delimiter: str = '\t', dtypes:list = []) -> None:
    """
    Save a NumPy array of mixed types (object dtype) to a .dat file.

    Parameters
    ----------
    filename : str
        Path to the .dat file.
    array : np.ndarray
        A 2D NumPy array with mixed types (dtype=object or structured).
    header : list of str, optional
        List of column headers (default: None).
    delimiter : str
        Delimiter between fields (default: tab).

    Raises
    ------
    ValueError
        If the array is not 2D or has inconsistent row lengths.
    """
    try:
        if array.ndim != 2:
            raise ValueError("Only 2D arrays are supported.")

        with open(filename, 'w', encoding='utf-8') as f:
            if header:
                if len(header) != array.shape[1]:
                    raise ValueError("Header length does not match number of columns.")
                f.write(delimiter.join(header) + '\n')

            for row in array:
                formatted = delimiter.join(str(dtypes[k](cell)) for k,cell in enumerate(row))
                f.write(formatted + '\n')

    except Exception as e:
        frame = inspect.currentframe()
        info = inspect.getframeinfo(frame)
        logger.error(
            f"Failed to write .dat file '{filename}' at {info.filename}:{info.lineno} in {info.function}()",
            exc_info=True
        )
        raise

# %%
sim_nn_filename = "intensity_mean_heatmap_NeuralABM_low_noise_row_margin_thinning1_burnin10000"


sim_nn_residual_arr = []
for i in range(sim_nn_residual.sizes['origin']+1):
    for j in range(sim_nn_residual.sizes['destination']+1):
        if i == 0 or j == 0:
            sim_nn_residual_arr.append([i,j,0,ZERO_COLOR])
        else:
            sim_nn_residual_arr.append([i,j,sim_nn_residual.values[i-1,j-1],normalise_to_flow_colorscale(sim_nn_residual.values[i-1,j-1])])
write_mixed_numpy_to_dat(
    os.path.join(output_path,sim_nn_filename+"_cell_data.dat"), 
    np.array(sim_nn_residual_arr), 
    header=["x","y","z","color"],
    dtypes=[int,int,float,float]
)

sim_nn_residual_demand_arr = []
for j in range(sim_nn_residual_demand.sizes['destination']):
    sim_nn_residual_demand_arr.append([69,j,sim_nn_residual_demand.values[j],normalise_to_demand_colorscale(sim_nn_residual_demand.values[j])])
for j in range(sim_nn_residual_demand.sizes['destination']):
    sim_nn_residual_demand_arr.append([70,j,sim_nn_residual_demand.values[j],normalise_to_demand_colorscale(sim_nn_residual_demand.values[j])])
write_mixed_numpy_to_dat(
    os.path.join(output_path,sim_nn_filename+"_destination_demand_cell_data.dat"), 
    np.array(sim_nn_residual_demand_arr), 
    header=["x","y","z","color"],
    dtypes=[int,int,float,float]
)

sim_nn_cps = []
for i in range(simnn_intensity_cp.sizes['origin']):
    for j in range(simnn_intensity_cp.sizes['destination']):
        if simnn_intensity_cp.values[i,j]:
            sim_nn_cps.append([i,j])
write_mixed_numpy_to_dat(
    os.path.join(output_path,sim_nn_filename+"_covered_cell_coordinates.dat"), 
    np.array(sim_nn_cps), 
    header=["x","y"],
    dtypes=[int,int]
)

# %%
sim_mcmc_filename = "intensity_mean_heatmap_SIMLatentMCMC_high_noise_row_margin_thinning1_burnin10000"

sim_mcmc_residual_arr = []
for i in range(sim_mcmc_residual.sizes['origin']):
    for j in range(sim_mcmc_residual.sizes['destination']):
        sim_mcmc_residual_arr.append([i,j,sim_mcmc_residual.values[i,j],normalise_to_flow_colorscale(sim_mcmc_residual.values[i,j])])
np.savetxt(
    os.path.join(output_path,sim_mcmc_filename+"_cell_data.txt"), 
    np.array(sim_mcmc_residual_arr), 
    header="x y z color", 
    comments='', 
    fmt="%.6f"
)
sim_mcmc_residual_demand_arr = []
for j in range(sim_mcmc_residual_demand.sizes['destination']):
    sim_mcmc_residual_demand_arr.append([69,j,sim_mcmc_residual_demand.values[j],normalise_to_demand_colorscale(sim_mcmc_residual_demand.values[j])])
for j in range(sim_mcmc_residual_demand.sizes['destination']):
    sim_mcmc_residual_demand_arr.append([70,j,sim_mcmc_residual_demand.values[j],normalise_to_demand_colorscale(sim_mcmc_residual_demand.values[j])])
np.savetxt(
    os.path.join(output_path,sim_mcmc_filename+"_destination_demand_cell_data.txt"), 
    np.array(sim_mcmc_residual_demand_arr), 
    header="x y z color", 
    comments='', 
    fmt="%.6f"
)
sim_mcmc_cps = []
for i in range(sim_mcmc_intensity_cp.sizes['origin']):
    for j in range(sim_mcmc_intensity_cp.sizes['destination']):
        if sim_mcmc_intensity_cp.values[i,j]:
            sim_mcmc_cps.append([i,j])
np.savetxt(
    os.path.join(output_path,sim_mcmc_filename+"_covered_cell_coordinates.txt"), 
    np.array(sim_mcmc_cps), 
    header="x y", 
    comments='', 
    fmt="%.6f"
)

# %%
sit_mcmc_filename = "table_mean_heatmap_JointTableSIMLatentMCMC_high_noise_row_margin_thinning1_burnin10000"

sit_mcmc_residual_arr = []
for i in range(sit_mcmc_residual.sizes['origin']):
    for j in range(sit_mcmc_residual.sizes['destination']):
        sit_mcmc_residual_arr.append([i,j,sit_mcmc_residual.values[i,j],normalise_to_flow_colorscale(sit_mcmc_residual.values[i,j])])
np.savetxt(
    os.path.join(output_path,sit_mcmc_filename+"_cell_data.txt"), 
    np.array(sit_mcmc_residual_arr), 
    header="x y z color", 
    comments='', 
    fmt="%.6f"
)
sit_mcmc_residual_demand_arr = []
for j in range(sit_mcmc_residual_demand.sizes['destination']):
    sit_mcmc_residual_demand_arr.append([69,j,sit_mcmc_residual_demand.values[j],normalise_to_demand_colorscale(sit_mcmc_residual_demand.values[j])])
for j in range(sit_mcmc_residual_demand.sizes['destination']):
    sit_mcmc_residual_demand_arr.append([70,j,sit_mcmc_residual_demand.values[j],normalise_to_demand_colorscale(sit_mcmc_residual_demand.values[j])])
np.savetxt(
    os.path.join(output_path,sit_mcmc_filename+"_destination_demand_cell_data.txt"), 
    np.array(sit_mcmc_residual_demand_arr), 
    header="x y z color", 
    comments='', 
    fmt="%.6f"
)
sit_mcmc_cps = []
for i in range(sit_mcmc_table_cp.sizes['origin']):
    for j in range(sit_mcmc_table_cp.sizes['destination']):
        if sit_mcmc_table_cp.values[i,j]:
            sit_mcmc_cps.append([i,j])
np.savetxt(
    os.path.join(output_path,sit_mcmc_filename+"_covered_cell_coordinates.txt"), 
    np.array(sit_mcmc_cps), 
    header="x y", 
    comments='', 
    fmt="%.6f"
)
